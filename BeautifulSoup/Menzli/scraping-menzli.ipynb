# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import time
import random
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def fix_encoding(text):
    """Handle common encoding issues in Tunisian/French text"""
    if not text:
        return ""
        
    # Try different encoding approaches
    for encoding in ['utf-8', 'latin1', 'windows-1252']:
        try:
            decoded = text.encode('raw_unicode_escape').decode(encoding)
            return decoded
        except:
            continue
    
    # Return original if all decoding fails
    return text

def clean_text(text):
    """Clean text by removing extra spaces and fixing encoding issues"""
    if not text:
        return ""
    
    # Apply encoding fixes first
    text = fix_encoding(text)
            
    # Then clean whitespace and special characters
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Common character replacements
    replacements = {
        'Ã©': 'é', 'Ã¨': 'è', 'Ã´': 'ô', 'Ã§': 'ç',
        'Ã¢': 'â', 'Ã¯': 'ï', 'Ãª': 'ê', 'Ã ': 'à',
        'Ã®': 'î', 'Ã»': 'û', 'Ã«': 'ë', 'Ã¹': 'ù',
        'Â': '', 'â': "'", 'Ã¤': 'ä', 'Ã¶': 'ö',
        'Ã¼': 'ü', 'Ã': 'À', 'Ã': 'É'
    }
    for old, new in replacements.items():
        text = text.replace(old, new)
        
    return text

def extract_pieces(soup, html_content):
    """Extract the number of pieces/rooms from various possible HTML structures"""
    result = None
    
    # Try direct approach first with encoding variations
    piece_variants = [
        'PiÃ©ces (Totale)', 'Piéces (Totale)', 'Pieces (Totale)', 
        'PiÃ©ces', 'Piéces', 'Pieces', 'Pièces', 'Pièce'
    ]
    
    # First try: Standard BeautifulSoup approach with various text patterns
    for variant in piece_variants:
        piece_element = soup.find('span', string=lambda text: text and variant in text if text else False)
        if piece_element and piece_element.find_next('strong'):
            result = piece_element.find_next('strong').get_text(strip=True)
            print(f"Found pieces with variant '{variant}': {result}")
            return result
    
    # Second try: More flexible regex pattern on HTML content
    patterns = [
        r'<span>Pi[éÃ]ces \(Totale\) : </span>\s*<strong>(\d+)',
        r'<span>Pi[éÃ]ces : </span>\s*<strong>(\d+)',
        r'<span>[^<]*Pi[éÃ]ces[^<]*</span>\s*<strong>(\d+)',
        r'Pi[éÃ]ces[^:]*:\s*</span>\s*<strong>(\d+)',
        r'Pi[èéÃ]ces.*?</span>\s*<strong>(\d+)'
    ]
    
    for pattern in patterns:
        match = re.search(pattern, html_content, re.IGNORECASE)
        if match:
            result = match.group(1)
            print(f"Found pieces with regex pattern: {result}")
            return result
    
    # Third try: Look for div content with pieces information
    divs = soup.select('.block-over')
    for div in divs:
        text = div.get_text(' ', strip=True)
        if any(variant.lower() in text.lower() for variant in piece_variants):
            # Extract the number using regex
            match = re.search(r'(\d+)', text)
            if match:
                result = match.group(1)
                print(f"Found pieces from div text: {result}")
                return result
                
    # Fourth try: Direct search in block-over divs
    for div in soup.select('.block-over'):
        span = div.select_one('span')
        if span and any(piece_term in span.get_text().lower() for piece_term in ['pièce', 'piece', 'piéce']):
            strong = div.select_one('strong')
            if strong:
                result = strong.get_text(strip=True)
                print(f"Found pieces from direct div search: {result}")
                return result
    
    return result

def scrape_property_details(url, title, max_retries=3):
    # Set up session with retry logic
    session = requests.Session()
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"]
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("https://", adapter)
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'fr-FR,fr;q=0.9',
        'Connection': 'keep-alive'
    }

    try:
        print(f"Scraping details for: {title}")

        # Add a small delay before requesting the details page
        time.sleep(random.uniform(0.5, 1.5))

        # Fetch the page with retry logic
        for attempt in range(max_retries):
            try:
                response = session.get(url, headers=headers, timeout=30)
                response.raise_for_status()
                break
            except requests.exceptions.RequestException as e:
                if attempt < max_retries - 1:
                    backoff_time = (2 ** attempt) * random.uniform(1, 2)
                    print(f"Failed to fetch details (attempt {attempt+1}): {e}. Retrying in {backoff_time:.2f}s...")
                    time.sleep(backoff_time)
                else:
                    print(f"Failed to fetch property details after {max_retries} attempts: {e}")
                    return None
        
        # Try different encodings
        for encoding in ['utf-8', 'latin1', 'windows-1252']:
            try:
                response.encoding = encoding
                html_content = response.text
                soup = BeautifulSoup(html_content, 'html.parser')
                break
            except UnicodeDecodeError:
                continue

        # Initialize result dictionary
        result = {
            "property_type": "Appartement",
            "property_details": {
                "chambres": None,
                "salle_de_bain": None,
                "pieces": None,
                "surface_habitable": None,
                "surface_terrain": None,
                "annee_construction": None
            },
            "options": [],
            "description": None,
            "images": []
        }

        # Property Details
        try:
            # Extract all property detail rows to debug
            detail_rows = soup.select('.detail-piece span')
            property_details_raw = {}
            
            # Print the raw details for debugging
            for detail in detail_rows:
                detail_text = detail.get_text().strip()
                if detail_text and ':' not in detail_text:
                    continue
                
                if detail.find_next('strong'):
                    key = detail_text.replace(':', '').strip()
                    value = detail.find_next('strong').get_text().strip()
                    property_details_raw[key] = value
                    print(f"Found detail: {key} = {value}")

            # Get pieces using the specialized function
            result["property_details"]["pieces"] = extract_pieces(soup, html_content)
            print(f"Extracted pieces: {result['property_details']['pieces']}")
            
            # Chambres (Bedrooms)
            if result["property_details"]["chambres"] is None:
                chambres_element = soup.find('span', string=lambda text: text and ('Chambres' in text or 'chambres' in text) if text else False)
                if chambres_element and chambres_element.find_next('strong'):
                    result["property_details"]["chambres"] = chambres_element.find_next('strong').get_text(strip=True)
                else:
                    # Fallback to regex for chambres
                    chambres_match = re.search(r'Chambres\s*:\s*</span>\s*<strong>(\d+)', html_content)
                    if chambres_match:
                        result["property_details"]["chambres"] = chambres_match.group(1)
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and 'chambre' in div.select_one('span').get_text().lower():
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["chambres"] = strong.get_text(strip=True)
                                    break

            # Salle de bain (Bathroom)
            if result["property_details"]["salle_de_bain"] is None:
                sdb_element = soup.find('span', string=lambda text: text and ('Salle de bain' in text or 'salle de bain' in text) if text else False)
                if sdb_element and sdb_element.find_next('strong'):
                    result["property_details"]["salle_de_bain"] = sdb_element.find_next('strong').get_text(strip=True)
                else:
                    # Fallback to regex for salle de bain
                    salle_match = re.search(r'Salle de bain\s*:\s*</span>\s*<strong>(\d+)', html_content)
                    if salle_match:
                        result["property_details"]["salle_de_bain"] = salle_match.group(1)
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and 'salle de bain' in div.select_one('span').get_text().lower():
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["salle_de_bain"] = strong.get_text(strip=True)
                                    break

            # Surface habitable (Living area)
            if result["property_details"]["surface_habitable"] is None:
                surf_hab_element = soup.find('span', string=lambda text: text and ('Surf habitable' in text or 'Surface habitable' in text) if text else False)
                if surf_hab_element and surf_hab_element.find_next('strong'):
                    result["property_details"]["surface_habitable"] = clean_text(surf_hab_element.find_next('strong').get_text(strip=True))
                else:
                    # Fallback to regex
                    surf_hab_match = re.search(r'Surf habitable\s*:\s*</span>\s*<strong>([^<]+)', html_content)
                    if surf_hab_match:
                        result["property_details"]["surface_habitable"] = clean_text(surf_hab_match.group(1))
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and any(term in div.select_one('span').get_text().lower() for term in ['surf habitable', 'surface habitable']):
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["surface_habitable"] = clean_text(strong.get_text(strip=True))
                                    break

            # Surface terrain (Land area)
            if result["property_details"]["surface_terrain"] is None:
                surf_terr_element = soup.find('span', string=lambda text: text and ('Surf terrain' in text or 'Surface terrain' in text) if text else False)
                if surf_terr_element and surf_terr_element.find_next('strong'):
                    result["property_details"]["surface_terrain"] = clean_text(surf_terr_element.find_next('strong').get_text(strip=True))
                else:
                    # Fallback to regex
                    surf_terr_match = re.search(r'Surf terrain\s*:\s*</span>\s*<strong>([^<]+)', html_content)
                    if surf_terr_match:
                        result["property_details"]["surface_terrain"] = clean_text(surf_terr_match.group(1))
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and any(term in div.select_one('span').get_text().lower() for term in ['surf terrain', 'surface terrain']):
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["surface_terrain"] = clean_text(strong.get_text(strip=True))
                                    break

            # Année construction (Construction year)
            if result["property_details"]["annee_construction"] is None:
                annee_element = soup.find('span', string=lambda text: text and ('Année construction' in text or 'Annee construction' in text) if text else False)
                if annee_element and annee_element.find_next('strong'):
                    result["property_details"]["annee_construction"] = clean_text(annee_element.find_next('strong').get_text(strip=True))
                else:
                    # Try multiple regex patterns for année construction
                    annee_patterns = [
                        r'Ann[ée]e construction\s*:\s*</span>\s*<strong>([^<]+)',
                        r'Ann[ée]e de construction\s*:\s*</span>\s*<strong>([^<]+)'
                    ]
                    
                    for pattern in annee_patterns:
                        annee_match = re.search(pattern, html_content, re.IGNORECASE)
                        if annee_match:
                            result["property_details"]["annee_construction"] = clean_text(annee_match.group(1))
                            break
                    
                    if result["property_details"]["annee_construction"] is None:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and any(term in div.select_one('span').get_text().lower() for term in ['année construction', 'annee construction']):
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["annee_construction"] = clean_text(strong.get_text(strip=True))
                                    break
                            
            # Debug message to track extraction success
            print(f"Extracted details - Rooms: {result['property_details']['pieces']}, Year: {result['property_details']['annee_construction']}")
            
        except Exception as e:
            print(f"Error getting property details: {e}")

        # Options
        try:
            # Try direct BeautifulSoup approach first
            option_elements = soup.select('span.col-md-4 strong i.fa-check-square')
            if option_elements:
                options = []
                for element in option_elements:
                    parent = element.parent
                    if parent and parent.get_text():
                        option_text = clean_text(parent.get_text().replace('✓', '').strip())
                        if option_text:
                            options.append(option_text)
                
                if options:
                    result["options"] = options
                else:
                    # Fallback to regex
                    options_matches = re.findall(r'<span class="col-md-4[^>]+><strong>\s*<i class="fa fa-check-square"></i>\s*([^<]+)</strong>', html_content)
                    if options_matches:
                        result["options"] = [clean_text(opt) for opt in options_matches if opt.strip()]
                        
            # If still no options, try another approach with span-opts class
            if not result["options"]:
                option_spans = soup.select('span.span-opts strong')
                if option_spans:
                    result["options"] = [clean_text(span.get_text().replace('✓', '').strip()) for span in option_spans if span.get_text().strip()]
            
        except Exception as e:
            print(f"Error getting options: {e}")

        # Description
        try:
            desc = soup.find('p', itemprop='text')
            if desc:
                result["description"] = clean_text(desc.get_text())
            else:
                # Try finding the description in other ways
                desc_element = soup.find('div', class_='detail-desc')
                if desc_element:
                    p_elements = desc_element.find_all('p')
                    if p_elements:
                        result["description"] = clean_text(" ".join([p.get_text() for p in p_elements]))
        except Exception as e:
            print(f"Error getting description: {e}")

        # Images
        try:
            images = soup.select('div.slider-product img[src]')
            if images:
                result["images"] = list(set([img['src'] for img in images]))
        except Exception as e:
            print(f"Error getting images: {e}")

        return result

    except Exception as e:
        print(f"Error scraping property details: {e}")
        return None

def scrape_property_listings(base_url, page_number, max_retries=3):
    # Construct URL with page number
    url = f"{base_url}?l=0&page={page_number}&tri=1"

    # Set up session with retry logic
    session = requests.Session()
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=1,  # Will sleep for 1s, then 2s, then 4s between retries
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"]
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("https://", adapter)

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'fr-FR,fr;q=0.9',
        'Connection': 'keep-alive'
    }

    try:
        # Fetch the page with retry logic
        for attempt in range(max_retries):
            try:
                print(f"Scraping page: {url} (Attempt {attempt+1}/{max_retries})")
                response = session.get(url, headers=headers, timeout=30)  # Increased timeout to 30s
                response.raise_for_status()
                break
            except requests.exceptions.RequestException as e:
                if attempt < max_retries - 1:
                    backoff_time = (2 ** attempt) * random.uniform(1, 2)
                    print(f"Error fetching the page (attempt {attempt+1}): {e}")
                    print(f"Waiting {backoff_time:.2f} seconds before retrying...")
                    time.sleep(backoff_time)
                else:
                    print(f"Failed to fetch page {page_number} after {max_retries} attempts")
                    return []

        # Try different encodings
        for encoding in ['utf-8', 'latin1', 'windows-1252']:
            try:
                response.encoding = encoding
                html_content = response.text
                soup = BeautifulSoup(html_content, 'html.parser')
                break
            except UnicodeDecodeError:
                continue

        # Find all property listings
        listings = soup.find_all('div', class_='li-item-list')
        
        if not listings:
            print(f"Warning: No listings found on page {page_number}. Response length: {len(response.text)}")
            # Try to save the HTML for debugging
            with open(f'debug_page_{page_number}.html', 'w', encoding='utf-8') as f:
                f.write(response.text)
            
        properties = []

        for listing in listings:
            try:
                # Extract basic listing information
                title_element = listing.find('a', class_='li-item-list-title')
                title = title_element.get_text(strip=True) if title_element else "No title found"
                title = clean_text(title)

                # Premium tag might not exist for all listings
                premium_tag = listing.find('span', class_='strap-premium')
                premium = premium_tag.get_text(strip=True) if premium_tag else "Standard"

                price_element = listing.find('span', class_='item-box-price')
                price = price_element.get_text(strip=True) if price_element else "Price not specified"
                
                link_element = listing.find('a', class_='li-item-list-title')
                link = link_element['href'] if link_element and 'href' in link_element.attrs else None

                # More robust location finding
                location_element = (
                    listing.find('p', class_='location') or 
                    (listing.find('i', class_='fa-map-marker').find_parent() if listing.find('i', class_='fa-map-marker') else None)
                )
                
                location = "Location not specified"
                if location_element:
                    location = location_element.get_text(' ', strip=True)
                    location = clean_text(location)

                # If location contains comma, split into neighborhood and city
                neighborhood, city = None, None
                if location and ',' in location:
                    parts = [part.strip() for part in location.split(',')]
                    neighborhood = parts[0] if len(parts) > 0 else None
                    city = parts[1] if len(parts) > 1 else None

                # Skip if we don't have a valid link
                if not link:
                    print(f"Skipping listing with no link: {title}")
                    continue

                # Scrape full property details
                full_property_details = scrape_property_details(link, title)

                # Create property dictionary
                property_data = {
                    "title": title,
                    "premium": premium,
                    "price": price,
                    "link": link,
                    "location": location,
                    "neighborhood": neighborhood,
                    "city": city
                }
                
                # Add property details if available
                if full_property_details:
                    property_data.update(full_property_details)

                properties.append(property_data)

                # Add more randomized delay between requests to property details
                time.sleep(random.uniform(1.5, 3.5))

            except Exception as e:
                print(f"Error processing a listing: {e}")
                continue

        return properties

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Function to save partial data periodically
def save_partial_data(properties, filename='menzili_properties_partial.json'):
    try:
        json_output = json.dumps(properties, indent=2, ensure_ascii=False)
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(json_output)
        print(f"Saved {len(properties)} properties to {filename}")
    except Exception as e:
        print(f"Error saving partial data: {e}")

# Main execution
if __name__ == "__main__":
    # You can change this URL to scrape maisons (houses) instead of apartments
    base_url = "https://www.menzili.tn/immo/vente-appartement-neuf-tunisie"
    # Uncomment the line below to scrape houses instead
    # base_url = "https://www.menzili.tn/immo/vente-maison-tunisie"
    
    all_properties = []
    save_interval = 10  # Save data every 10 pages
    
    # For initial testing, start with just a few pages
    # Once verified working, expand to more pages
    start_page = 1
    end_page = 366  # Start with just 5 pages for testing
    
    try:
        for page in range(start_page, end_page + 1):
            try:
                # Scrape properties from current page
                page_properties = scrape_property_listings(base_url, page)

                # Add properties to the main list
                all_properties.extend(page_properties)

                # Print progress
                print(f"Completed page {page}. Total properties so far: {len(all_properties)}")

                # Save partial data periodically
                if page % save_interval == 0:
                    save_partial_data(all_properties)

                # More randomized delay between pages
                delay = random.uniform(3, 7)
                print(f"Waiting {delay:.2f} seconds before next page...")
                time.sleep(delay)

            except Exception as e:
                print(f"Error scraping page {page}: {e}")
                # Save partial data on error
                save_partial_data(all_properties, f'menzili_properties_error_at_page_{page}.json')
                continue

    except KeyboardInterrupt:
        print("\nScraping interrupted by user. Saving collected data...")
        save_partial_data(all_properties, 'menzili_properties_interrupted.json')
    
    # Save the final data
    if all_properties:
        # Convert to JSON
        json_output = json.dumps(all_properties, indent=2, ensure_ascii=False)

        # Save to file
        with open('menzili_properties_data.json', 'w', encoding='utf-8') as f:
            f.write(json_output)

        print("Scraping completed. Data saved to menzili_properties_data.json")
        print(f"Total properties scraped: {len(all_properties)}")
    else:
        print("No properties were scraped. Check the website availability or your network connection.")
# Out:
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=1&tri=1 (Attempt 1/3)
# Scraping details for: A vendre Appartement au lac 2
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement S3 à vendre à la Marsa
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement S+1 à La Marsa MAV1613
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À VENDRE appartement à la SOUKRA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2022
# Scraping details for: Un appartement S+1 tout neuf à vendre à AFH Mrezga 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: A vendre appartement au centre urbain Nord Tunis
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2008
# Scraping details for: À VENDRE APPARTEMENT S3 JARDINS DE CARTHAGE
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2012
# Scraping details for: Appartement RDC S+2 tout neuf à vendre à Manaret El Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2021
# Scraping details for: Appartement S+1 à sidi mahersi Nabeul
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+2 à Mrezga 5min de la plage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2023
# Scraping details for: Appartement équipé près de Mansoura
# Found pieces with variant 'Piéces (Totale)': 7
# Extracted pieces: 7
# Extracted details - Rooms: 7, Year: 2012
# Scraping details for: Villa CIEL DES ETOILES (Réf: V2897)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: VENTE S+2 a Medina jadida 3
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A VENDRE COQUET APPARTEMENT S2 A NOUVELLE MÉDINA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: À Vendre Appartement S+3 avec parking proche de la plage à mahdia
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: à vendre s+2 neuf et vue sur mer à baghdedi plage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement meublé à louer à Sidi Daoud, La Marsa
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2015
# Scraping details for: Appartement
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartement S+2 au village méditerranéen
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2001
# Scraping details for: À VENDRE : Un appartement S+2 situé à La Nouvelle Soukra ( Direct promoteur )
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 1. Total properties so far: 20
# Waiting 6.48 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=2&tri=1 (Attempt 1/3)
# Scraping details for: Coquet studio à vendre à 140 MD à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre un S+2 direct promoteur
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2024
# Scraping details for: A vendre un S+3 à Sahloul
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2008
# Scraping details for: A vendre un S+1 avec une terrasse
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: Un appartement s1 neuf à ain zaghouan
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S+3 à Yasmine Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement sur plant a ENNASSR 2
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2024
# Scraping details for: Appartement S+1.2.3 a vendre ENNASSR 2
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartement S+1 avec jardin à vendre à AFH Mrezga 51355351
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartement S+3 vue de mer
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A vendre appartement S+3 à la résidence Folla, Monastir
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A vendre appartement S+1 Direct Promoteur
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement Direct Promoteur a deux pas de la mer
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre appartement S+2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un appartement s+2 à louer située à sahloul4
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 vue de mer à vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement 4 pièces la Fayette
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Un appartement S+2 à Hammamet Nord à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2025
# Scraping details for: À vendre un unique S2 independent (1er étage) avec terrasse
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre appartement S+1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 2. Total properties so far: 40
# Waiting 6.44 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=3&tri=1 (Attempt 1/3)
# Scraping details for: Appartement au centre de Tunis
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement neuf S+3 avec piscine à AFH2 à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2024
# Scraping details for: Deux appartements à vendre à Sidi Achour Nabeul 51355351
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: 4 appartements tout neuf à Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 10+
# Extracted pieces: 10+
# Extracted details - Rooms: 10+, Year: 2023
# Scraping details for: Des appartements S+2 tout neuf à vendre à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2022
# Scraping details for: Bel appartement S+3 vue de mer à vendre à Nabeul 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Charmant S0 avec Balcon à Jardins de Carthage
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: À VENDRE : Appartement S+2 à Tunis Belvédère
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Des appartements S2 et S3 récemment construite
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Studio à Port marina El Kantaoui
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement S1 à PALM LAKE FOLLA
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Un spacieux appartement S+2 RDC à vendre à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement en s2 A vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre une Chic S3 à Khzema Est
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Studio au berges du lac
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S3 sur avenue Taher ben Ammar
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À Vendre \u2013 Appartement S+3 à Hedi Nouira, Borj Louzir
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement s1 center ville
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre S2 à sahloul neuf
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Av appartement vue mer à salloum bouficha
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 3. Total properties so far: 60
# Waiting 5.52 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=4&tri=1 (Attempt 1/3)
# Scraping details for: Appartement RDC S+1 avec jardin à Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement vue de mer S+3 avec piscine à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement s+2 / s+3 à Madina jadida jamais habitée
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Un S+1 à Vendre
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Un appartement S+2 à Hammamet Nord à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2025
# Scraping details for: Appartement S+2 à Menzah 9C
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+1 / s+2 à Bir kassaa jamais habitée
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement neuf S+3 avec piscine à AFH2 à vendre 51355351
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: 4 appartements tout neuf à Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 10+
# Extracted pieces: 10+
# Extracted details - Rooms: 10+, Year: 2023
# Scraping details for: Des appartements S+2 tout neuf à vendre à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2022
# Scraping details for: Un Appartement S de 109m² à La Nouvelle Medina
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Bel appartement S+2 à vendre à Yasmine Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: APPARTEMENT JAMAIS HABITEE
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S2 avec vue sur mer à vendre \u2013 Zone Touristique Mahdia
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S+3 à Yasmine Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Un appartement s+2 à ain zaghouan
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement RDC S+2 tout neuf à vendre à Manaret El Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2022
# Scraping details for: A vendre appartement à la place de Barcelone
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Coquet studio à vendre à 140 MD à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Vente Appartement Silver à Hammamet
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2024
# Completed page 4. Total properties so far: 80
# Waiting 5.22 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=5&tri=1 (Attempt 1/3)
# Scraping details for: Appart S4 Alain Savary
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: S2 Haut standing Soukra
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Un spacieux appartement S+2 RDC à vendre à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement Phenicia P
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement Phenicia
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: À VENDRE APPARTEMENT S+3 À RADES PLAGE
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre bel appartement S2 à hergla
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Bel appartement S+3 vue de mer à vendre à Nabeul 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Penthouse Gris
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 Meublé à Louer - Aouina, Tunis
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 hiboun zone touristique
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2015
# Scraping details for: Un appartement S+1 tout neuf à vendre à AFH Mrezga 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: Bel appartement S+1 à vendre à AFH Mrezga 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2023
# Scraping details for: Appartement S1 Jamais habité à Mahdia
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement en Duplex S4
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartement S+1 avec jardin à vendre à AFH Mrezga 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: À vendre un appartement S+2 situé à KELIBIA 27246313
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: A vendre un appartement s+2 Hammamet \u260e +27246313
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: Appartement S+1 avec vue de mer à Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: À vendre un appartement à YASMINE HAMMAMET 27246313
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2024
# Completed page 5. Total properties so far: 100
# Waiting 3.79 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=6&tri=1 (Attempt 1/3)
# Scraping details for: Un appartement s+1 situé à mrezga 27246313
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2024
# Scraping details for: Appartement s2 a vendre à Ennaser 2
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: À vendre un appartement S+1 situé à MREZGA 27246313
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2024
# Scraping details for: Apparement s+1 a vendre à Ennaser 2
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2024
# Scraping details for: Appartement S+3 à Ain Zaghouan MAV1819
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+3 de 134 m²
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2022
# Scraping details for: Coquet appartement S+2 à Hammamet à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Bel Appartement vue mer zone touristique de Shango
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2013
# Scraping details for: Un appartement S3 de 136 m² à Nouvelle Médina - Direct Promoteur
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un Appartement S1 de 68 m² à Nouvelle Médina - Vente directe promoteur
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement a vendre cité olympique rades
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2001
# Scraping details for: Un appartement S2 de 110 m² à Nouvelle Médina - Direct Promoteur
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement à Cité Zitouna
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un Appartement S2 - Direct Promoteur
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement à vendre à le bardo
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Particulier met en vente unApp s+3 au Jardains d' Elmenzeh 1
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2007
# Scraping details for: Appartement neuf dans la zone touristique Monastir
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+1 au 2eme étage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2014
# Scraping details for: Appartement S+2 de 160 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un appartement S+1 avec balcon
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 6. Total properties so far: 120
# Waiting 6.68 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=7&tri=1 (Attempt 1/3)
# Scraping details for: Appartement S+2 de 85m² à Kélibia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2022
# Scraping details for: A vendre appartement de 85 m² à kélibia
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: V518 Appartement SEPHORA 1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: V519 Appartement SEPHORA 2
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Deux appartements à vendre à Sidi Achour Nabeul 51355351
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Un spacieux appartement S+2 RDC à vendre à Nabeul 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2024
# Scraping details for: Bonne affaire à sfax
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Vente appartement s+2 à sfax
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 1960
# Scraping details for: A vendre S+3 neuf a Menzah 9C
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement s+1 situé à AFH 2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Scraping details for: Appartement s+1 de 84m² à vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Scraping details for: Studio Promo
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S+3 à Vendre - Bab El Jazira Tunis Centre-ville
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S3 A KANTAOUI
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 de 90 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2020
# Scraping details for: Appartement S+2 situé à Hammamet à 2 km de hôtel Ribat
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2023
# Scraping details for: Appartement S+2 situé à Hammamet Nord
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2010
# Scraping details for: Superbe appartement s+3 à lac 1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+1 situé à Hammamet centre ville
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2014
# Scraping details for: Appartement S+1 à La Soukra MAL1422
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 7. Total properties so far: 140
# Waiting 5.61 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=8&tri=1 (Attempt 1/3)
# Scraping details for: Appartement bon standing s+2 à vendre à borj el baccouche, proche
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: à vendre appartement s+1 vue sur mer et pied dans l\u2019eau à corniche mahdia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: à vendre appartement s+1 vue sur mer à baghdedi plage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Petite immeuble de trois appartements avec garage à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Vente appartement
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre un appartement à Yasminette Ben Arous
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: S3 avec Jardin Ennaser 1
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un appartement s+2 à vendre située à sahloul1
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Un appartement s+1 à vendre situé à sahloul1
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Un appartement spacieux s+2 à vendre situé à sahloul1
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Un lumineux appartement s+2 à vendre situé à sahloul1
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement S+4 à l'aouina
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: A vendre un appartement s3 aux jardins de Carthage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+3 à Vendre à el Mourouj 1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Maison
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un appartement s+2 à vendre située à Diwen Zit souk ahd
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement s+2 bien équipée meublé a vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+2 de 91m² jamais habitée
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2025
# Scraping details for: S+2 de vue sur mer de 160m²
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Très haut standing comprenant 2 appartements
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2018
# Completed page 8. Total properties so far: 160
# Waiting 3.35 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=9&tri=1 (Attempt 1/3)
# Scraping details for: Appartement Asma AFH
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement de 107 m2 Sidi mansour km8
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2018
# Scraping details for: Appartement S3 à Jardin d'el Menzah 1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+2 medina jadida
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2017
# Scraping details for: Appartement vue de mer S+3 avec piscine à vendre à 320 MD 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 à La Soukra MAV1805
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre un appartement S+2 à Monastir
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un appartement S+2 à Mahdia
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2022
# Scraping details for: Des appartements S+2 à vendre à Hammamet 51355351
# Found pieces with variant 'Piéces (Totale)': 9
# Extracted pieces: 9
# Extracted details - Rooms: 9, Year: None
# Scraping details for: A vendre S2 à Khzema
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un S+4 à Vendre
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2017
# Scraping details for: À VENDRE APPARTEMENT S+4 HAUT STANDING À HAMMAMET MREZGA
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À VENDRE APPARTEMENT S+3 DE 108M² À LA NOUVELLE MEDINA
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À VENDRE APPARTEMENT S+2 COMPLÉTEMENT RÉNOVÉ À RADES SNIT
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À VENDRE APPARTEMENT S+2 AVEC CELLIER À RADES PLAGE
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À VENDRE APPARTEMENT S+2 EN PREMIER ÉTAGE À RADES PLAGE
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À VENDRE APPARTEMENT S+2 À CITÉ DISPENSAIRE DE BEN AROUS
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+1 la goulette tunis
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2015
# Scraping details for: S+2 a louer
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Vente S+3 à Jardin d'elmenzah
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Completed page 9. Total properties so far: 180
# Waiting 5.70 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=10&tri=1 (Attempt 1/3)
# Scraping details for: Penthouse à vendre à Khezema Route Touristique
# Found pieces with variant 'Piéces (Totale)': 10+
# Extracted pieces: 10+
# Extracted details - Rooms: 10+, Year: None
# Scraping details for: Rez-de-chaussée à vendre à Khezama Ouest
# Found pieces with variant 'Piéces (Totale)': 7
# Extracted pieces: 7
# Extracted details - Rooms: 7, Year: None
# Scraping details for: À VendreS2 de 118m² avec terrasse 45m² a Cité El WafaNabeul.
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Un Appartement S2 à Mourouj 6
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre un appartement meublé à l'Avenue Habib Thameur
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 à Ain Zaghouan El Wahat MAV1802
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: A vendre un Appartement au plein centre ville
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: À Vendre : Duplex S+2 à Bassatine, Monastir
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre des appartements neufs FOPROLOS 2 à Oued Ellil
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+4 avec terrasse à La Marsa MAV1804
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement s3 refait à neuf
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2022
# Scraping details for: A vendre S3 à Khzema Est
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Bel Appartement à tantana à vendre
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Vente appartement
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement Jinen
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre appartement 54833379
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un appartemnt à hammamet centre 27246313
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un appartement à Hammamet centre 27246313
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement Canal 590
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement Art
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 10. Total properties so far: 200
# Saved 200 properties to menzili_properties_partial.json
# Waiting 6.58 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=11&tri=1 (Attempt 1/3)
# Scraping details for: Un appartement à vendre à hammam sousse [clèopatre]
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement 3 pièces à Montfleury 90 MD
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2010
# Scraping details for: \u0634\u0642\u0642 \u0644\u0644\u0628\u064a\u0639
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+1 Haut Standing à Skanes
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre Cabinet Medical au lac 0
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 à La Nouvelle Soukra MAV1784
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Vente appartement s1 la soukra
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Scraping details for: Vente S+0 à Ennasr
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2010
# Scraping details for: Vente S+1 à Ennasr
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2005
# Scraping details for: Appartement S1 Lac 2
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: S1 meublé haut standing Ennaser 2
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement S3 Carthage Byrsa
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S2 Ghazela
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S1 Riadh Landalous
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement vue de mer S+3 avec piscine à vendre à 320 MD 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A vendre app Situé au 3ème étage sans ascenseur
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Vente Coquet appartement S3 à médina Jadida 3
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A VENDRE S2 A MEDINA JADIDA 3
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Un appartement S+2 avec piscine à vendre à Jinen Béni Khiar 51355351
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 avec jardin à La Soukra MAV1797
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Completed page 11. Total properties so far: 220
# Waiting 4.40 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=12&tri=1 (Attempt 1/3)
# Scraping details for: 2 appartements S+2 avec garage à vendre à Tazarka 51355351
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2022
# Scraping details for: Appartement S+2 à Hay El Wahat, Laaouina - Résidence Diar Soukra
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2 à Ain Zaghouan MAV1795
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement Galaxy 2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement Hkimi
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A louer sublime Penthouse meublé à khzema
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+1 à Ain Zaghouan MAV1794
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Promotion AFH
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Dar chaabane Plage vd appart S+3 de standing
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: À vendre un appartementde 90m²à KELIBIA
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre un appartement s+2 Hammamet 27246313
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Un appartement
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre Appartement S+3 Salons plus trois chambres Neuf à Manouba Ville 99425253
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2012
# Scraping details for: Des Appartements modernes à vendre à Hammam Al Ghezaz
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A VENDRE S3 A YASMINETTE
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: ????????????????????????????????
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un appartement s+2 à Yasmine Hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+2 à kelibia avec accès direct à la plage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Location un appartement meublé à Ain Zaghouan
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Bureau H+2 à Ain Zaghouan MBL0477
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 12. Total properties so far: 240
# Waiting 5.50 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=13&tri=1 (Attempt 1/3)
# Scraping details for: Direct du propriètaire Manar 2 FACE du consulat du maroc
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A Vendre Appartement S1 vue mer à Chatte Mariem
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: A vendre appartement S+2 à Tantana
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre Penthouse S+4 vue de mer
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: A vendre Appartement S+1 haut standing
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre appartement S+2 a deux pas de a la mer
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre Appartement S+2 Direct Promoteur
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+3 à La Soukra ZAV1436
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre Appartement S+2 Direct Promoteur Haut standing
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre Appartement S+2 Direct Promoteur Haut standing
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre Appartement S+2 Direct Promoteur Haut standing
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s3 à hay lamal la manouba
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartement S+3 à Tantana Chott Mariem
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A vendre appartement S+3 meublé à Khzema
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Coquet appartement à vendre dans la zone touristique 51355351
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S+3 pied dans l'eau à vendre à Nabeul 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement S+3 avec piscine à AFH2 à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Un Appartement S2 de 110 m² à Rades
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+2, 1ère étage au centre ville de kelibia cap bon
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement RDC a vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 13. Total properties so far: 260
# Waiting 4.69 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=14&tri=1 (Attempt 1/3)
# Scraping details for: Appartement S2 Cité la gazelle
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre : appartement S+2 à zone touristique Mahdia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Tecnocasa Nouvelle Medina met en #vente un appartement S+3 avec une superficie de 128m².
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2011
# Scraping details for: Nouvelle-Offre #A-VENDRE S+2 avec une superficie de 122m².
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2019
# Scraping details for: Nouvelle-Offre #A-VENDRE #S+2 avec une superficie de 122m².
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2019
# Scraping details for: Appartement S+3 avec piscine à vendre à 320 MD 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement s+3 a vendre à Ennaser
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+3 a vendre à La Soukra
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Joli Appartement S3 à vendre à hammem sousse
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement haut standing
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Bel Appartement S3 dans une résidence front mer
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Magnifique Appartement Front mer
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: À vendre S0 de 30m² à Hammamet nord coté Radisson.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+3 en excellent état
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2016
# Scraping details for: Appartement S+1 à vendre à AFH Mrezga 51355351
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+3 avec piscine à AFH2 à vendre 51355351
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2024
# Scraping details for: Vends appartement à TABARKA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# ...
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Des appartements sis à ksour essaf
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2015
# Scraping details for: Av un luxueux appartement. A l'aouina
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2013
# Scraping details for: RDC très lumineux grande terrasse superbe vue mer
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2015
# Scraping details for: Av appartement à l'aouina
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2013
# Scraping details for: Belle résidence
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Studio belle vue mer a 150 m de la plage situé au 4e étage
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2016
# Scraping details for: Grand studio neuf vue mer a 150m de la plage
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2016
# Scraping details for: Appartements s+1 et s+2 situés au rez de chaussee
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Immeuble neuf à vendre à rades plage
# Found pieces with variant 'Piéces (Totale)': 10+
# Extracted pieces: 10+
# Extracted details - Rooms: 10+, Year: None
# Scraping details for: Chourouk
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2003
# Scraping details for: Appartement à vendre à chott mariem (sousse)
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2012
# Scraping details for: A VENDRE APPARTEMENT
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Studio
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 1950
# Scraping details for: Bel appartement a vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2012
# Scraping details for: App HS La Ghazelle
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Completed page 361. Total properties so far: 6420
# Waiting 3.37 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=362&tri=1 (Attempt 1/3)
# Scraping details for: A vendre un appartement
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 1928
# Scraping details for: A vendre Appartement
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Un beau appartement S+3 spacieux en plein centre ville de sousse
# Found pieces with variant 'Piéces (Totale)': 7
# Extracted pieces: 7
# Extracted details - Rooms: 7, Year: 2014
# Scraping details for: Riadh 5
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Studio à Folla
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2013
# Scraping details for: Duplex Haut Standing Cite Ennasr 800
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement a rades a ne pas rater
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2015
# Scraping details for: Appartement S+3 au rez de chaussee +garage
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 1990
# Scraping details for: App a60 milles
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Avendre appartement
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+2 a vendre à Mahsouna Sfax
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: App a vendre a imb mahssouna
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Scraping details for: A vendre appart situé a cité de la promenade
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: None
# Scraping details for: S+3
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 207
# Scraping details for: Appartement 2eme étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 Haut Standing à "Kassas Centre"
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2016
# Scraping details for: App s+2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2000
# Scraping details for: App a vendre a imb mahssouna
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Scraping details for: Appartement s+2 à sfax
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 1990
# Scraping details for: Appartement S+3 Riadh Al Andalous
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Completed page 362. Total properties so far: 6440
# Waiting 6.18 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=363&tri=1 (Attempt 1/3)
# Scraping details for: à vendre ou à louer un appartement s plus 3
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2006
# Scraping details for: Appartement à vendre au cité jardin
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 1980
# Scraping details for: Appartement neuf au berge du lac 2 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement meublé au lac2
# Found pieces with variant 'Piéces (Totale)': 7
# Extracted pieces: 7
# Extracted details - Rooms: 7, Year: None
# Scraping details for: Appartement s+3 a Mornag
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Belle appartement sidi abbes
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2004
# Scraping details for: Appartements 140m2 à Tunis L'aouina
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartements S3 240m2 à Tunis L'aouina
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartements S3 170m2 à Tunis L'aouina
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Villa trés haut standing
# Found pieces with variant 'Piéces (Totale)': 8
# Extracted pieces: 8
# Extracted details - Rooms: 8, Year: None
# Scraping details for: étage a vendre kelibia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartements S3 à Tunis L'aouina
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartements 140m2 à Tunis L'aouina
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Apart bab bhar
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 1990
# Scraping details for: Appartement s+3 cite jardin
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement a jardin d el manzeh 2
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2009
# Scraping details for: Appartement haut standing
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Bel Appartements 98m2 à Lafayette
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 1962
# Scraping details for: Cause départ à vendre
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2010
# Scraping details for: S+2 de 95 m² à El Manar I
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 363. Total properties so far: 6460
# Waiting 6.47 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=364&tri=1 (Attempt 1/3)
# Scraping details for: Appartement s+1,au troisième étage luxueux
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement vue de mer meubler
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2015
# Scraping details for: Lot: 02 villas + studio + terrain
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2012
# Scraping details for: étage villa
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2005
# Scraping details for: Apprt à 3km de centre ville
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement retape à neuf
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Très jolie appartement Radés meliane
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2009
# Scraping details for: Appartement ndif
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2002
# Scraping details for: Appartement Rades cite Mohamed Ali
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+2 convertit en s+3 de 120 m 2 à el menzah 7
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Salon +3
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2000
# Scraping details for: Villa À Hammamet 468
# Found pieces with variant 'Piéces (Totale)': 8
# Extracted pieces: 8
# Extracted details - Rooms: 8, Year: None
# Scraping details for: Appartement Ghazella 210A17
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Vente App S+3 Riadh Andalous
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Immeuble à vendre à Bouhssina Sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Immeuble(r+2) à vendre Riadh Sousse
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: APARTEMENT CITE ERAHANA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2006
# Scraping details for: Appartement dans une petite résidence gardé
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement titré spacieux à hammam sousse
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement route habbana km 4 resedence errayahine
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2013
# Completed page 364. Total properties so far: 6480
# Waiting 3.81 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=365&tri=1 (Attempt 1/3)
# Scraping details for: Jardin d'el menzah
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2009
# Scraping details for: Apparemment à cité jardin sfax
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À vendre un bel appartement
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2000
# Scraping details for: Appartement erroukii marina vue mer
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2000
# Scraping details for: Appartemen s+3 a azzahra
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+3 ,au troisième étage luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement s+2 au troisième étage luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement s+1 au troisième étage luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement s+2 luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: A vendre appartement avec titre bleu
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2003
# Scraping details for: App. 2 + s à a Cité Latif2 Menzah7
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 1995
# Completed page 365. Total properties so far: 6491
# Waiting 4.92 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=366&tri=1 (Attempt 1/3)
# Scraping details for: Jardin d'el menzah
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2009
# Scraping details for: Apparemment à cité jardin sfax
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À vendre un bel appartement
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2000
# Scraping details for: Appartement erroukii marina vue mer
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2000
# Scraping details for: Appartemen s+3 a azzahra
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+3 ,au troisième étage luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement s+2 au troisième étage luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement s+1 au troisième étage luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: Appartement s+2 luxueux
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2017
# Scraping details for: A vendre appartement avec titre bleu
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2003
# Scraping details for: App. 2 + s à a Cité Latif2 Menzah7
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 1995
# Completed page 366. Total properties so far: 6502
# Waiting 7.00 seconds before next page...
# Scraping completed. Data saved to menzili_properties_data.json
# Total properties scraped: 6502

# %%
import requests
from bs4 import BeautifulSoup
import json
import re
import time
import random
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

def fix_encoding(text):
    """Handle common encoding issues in Tunisian/French text"""
    if not text:
        return ""
        
    # Try different encoding approaches
    for encoding in ['utf-8', 'latin1', 'windows-1252']:
        try:
            decoded = text.encode('raw_unicode_escape').decode(encoding)
            return decoded
        except:
            continue
    
    # Return original if all decoding fails
    return text

def clean_text(text):
    """Clean text by removing extra spaces and fixing encoding issues"""
    if not text:
        return ""
    
    # Apply encoding fixes first
    text = fix_encoding(text)
            
    # Then clean whitespace and special characters
    text = re.sub(r'\s+', ' ', text).strip()
    
    # Common character replacements
    replacements = {
        'Ã©': 'é', 'Ã¨': 'è', 'Ã´': 'ô', 'Ã§': 'ç',
        'Ã¢': 'â', 'Ã¯': 'ï', 'Ãª': 'ê', 'Ã ': 'à',
        'Ã®': 'î', 'Ã»': 'û', 'Ã«': 'ë', 'Ã¹': 'ù',
        'Â': '', 'â': "'", 'Ã¤': 'ä', 'Ã¶': 'ö',
        'Ã¼': 'ü', 'Ã': 'À', 'Ã': 'É'
    }
    for old, new in replacements.items():
        text = text.replace(old, new)
        
    return text

def extract_pieces(soup, html_content):
    """Extract the number of pieces/rooms from various possible HTML structures"""
    result = None
    
    # Try direct approach first with encoding variations
    piece_variants = [
        'PiÃ©ces (Totale)', 'Piéces (Totale)', 'Pieces (Totale)', 
        'PiÃ©ces', 'Piéces', 'Pieces', 'Pièces', 'Pièce'
    ]
    
    # First try: Standard BeautifulSoup approach with various text patterns
    for variant in piece_variants:
        piece_element = soup.find('span', string=lambda text: text and variant in text if text else False)
        if piece_element and piece_element.find_next('strong'):
            result = piece_element.find_next('strong').get_text(strip=True)
            print(f"Found pieces with variant '{variant}': {result}")
            return result
    
    # Second try: More flexible regex pattern on HTML content
    patterns = [
        r'<span>Pi[éÃ]ces \(Totale\) : </span>\s*<strong>(\d+)',
        r'<span>Pi[éÃ]ces : </span>\s*<strong>(\d+)',
        r'<span>[^<]*Pi[éÃ]ces[^<]*</span>\s*<strong>(\d+)',
        r'Pi[éÃ]ces[^:]*:\s*</span>\s*<strong>(\d+)',
        r'Pi[èéÃ]ces.*?</span>\s*<strong>(\d+)'
    ]
    
    for pattern in patterns:
        match = re.search(pattern, html_content, re.IGNORECASE)
        if match:
            result = match.group(1)
            print(f"Found pieces with regex pattern: {result}")
            return result
    
    # Third try: Look for div content with pieces information
    divs = soup.select('.block-over')
    for div in divs:
        text = div.get_text(' ', strip=True)
        if any(variant.lower() in text.lower() for variant in piece_variants):
            # Extract the number using regex
            match = re.search(r'(\d+)', text)
            if match:
                result = match.group(1)
                print(f"Found pieces from div text: {result}")
                return result
                
    # Fourth try: Direct search in block-over divs
    for div in soup.select('.block-over'):
        span = div.select_one('span')
        if span and any(piece_term in span.get_text().lower() for piece_term in ['pièce', 'piece', 'piéce']):
            strong = div.select_one('strong')
            if strong:
                result = strong.get_text(strip=True)
                print(f"Found pieces from direct div search: {result}")
                return result
    
    return result

def scrape_property_details(url, title, max_retries=3):
    # Set up session with retry logic
    session = requests.Session()
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=1,
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"]
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("https://", adapter)
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'fr-FR,fr;q=0.9',
        'Connection': 'keep-alive'
    }

    try:
        print(f"Scraping details for: {title}")

        # Add a small delay before requesting the details page
        time.sleep(random.uniform(0.5, 1.5))

        # Fetch the page with retry logic
        for attempt in range(max_retries):
            try:
                response = session.get(url, headers=headers, timeout=30)
                response.raise_for_status()
                break
            except requests.exceptions.RequestException as e:
                if attempt < max_retries - 1:
                    backoff_time = (2 ** attempt) * random.uniform(1, 2)
                    print(f"Failed to fetch details (attempt {attempt+1}): {e}. Retrying in {backoff_time:.2f}s...")
                    time.sleep(backoff_time)
                else:
                    print(f"Failed to fetch property details after {max_retries} attempts: {e}")
                    return None
        
        # Try different encodings
        for encoding in ['utf-8', 'latin1', 'windows-1252']:
            try:
                response.encoding = encoding
                html_content = response.text
                soup = BeautifulSoup(html_content, 'html.parser')
                break
            except UnicodeDecodeError:
                continue

        # Initialize result dictionary
        result = {
            "property_type": "Appartement",
            "property_details": {
                "chambres": None,
                "salle_de_bain": None,
                "pieces": None,
                "surface_habitable": None,
                "surface_terrain": None,
                "annee_construction": None
            },
            "options": [],
            "description": None,
            "images": []
        }

        # Property Details
        try:
            # Extract all property detail rows to debug
            detail_rows = soup.select('.detail-piece span')
            property_details_raw = {}
            
            # Print the raw details for debugging
            for detail in detail_rows:
                detail_text = detail.get_text().strip()
                if detail_text and ':' not in detail_text:
                    continue
                
                if detail.find_next('strong'):
                    key = detail_text.replace(':', '').strip()
                    value = detail.find_next('strong').get_text().strip()
                    property_details_raw[key] = value
                    print(f"Found detail: {key} = {value}")

            # Get pieces using the specialized function
            result["property_details"]["pieces"] = extract_pieces(soup, html_content)
            print(f"Extracted pieces: {result['property_details']['pieces']}")
            
            # Chambres (Bedrooms)
            if result["property_details"]["chambres"] is None:
                chambres_element = soup.find('span', string=lambda text: text and ('Chambres' in text or 'chambres' in text) if text else False)
                if chambres_element and chambres_element.find_next('strong'):
                    result["property_details"]["chambres"] = chambres_element.find_next('strong').get_text(strip=True)
                else:
                    # Fallback to regex for chambres
                    chambres_match = re.search(r'Chambres\s*:\s*</span>\s*<strong>(\d+)', html_content)
                    if chambres_match:
                        result["property_details"]["chambres"] = chambres_match.group(1)
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and 'chambre' in div.select_one('span').get_text().lower():
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["chambres"] = strong.get_text(strip=True)
                                    break

            # Salle de bain (Bathroom)
            if result["property_details"]["salle_de_bain"] is None:
                sdb_element = soup.find('span', string=lambda text: text and ('Salle de bain' in text or 'salle de bain' in text) if text else False)
                if sdb_element and sdb_element.find_next('strong'):
                    result["property_details"]["salle_de_bain"] = sdb_element.find_next('strong').get_text(strip=True)
                else:
                    # Fallback to regex for salle de bain
                    salle_match = re.search(r'Salle de bain\s*:\s*</span>\s*<strong>(\d+)', html_content)
                    if salle_match:
                        result["property_details"]["salle_de_bain"] = salle_match.group(1)
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and 'salle de bain' in div.select_one('span').get_text().lower():
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["salle_de_bain"] = strong.get_text(strip=True)
                                    break

            # Surface habitable (Living area)
            if result["property_details"]["surface_habitable"] is None:
                surf_hab_element = soup.find('span', string=lambda text: text and ('Surf habitable' in text or 'Surface habitable' in text) if text else False)
                if surf_hab_element and surf_hab_element.find_next('strong'):
                    result["property_details"]["surface_habitable"] = clean_text(surf_hab_element.find_next('strong').get_text(strip=True))
                else:
                    # Fallback to regex
                    surf_hab_match = re.search(r'Surf habitable\s*:\s*</span>\s*<strong>([^<]+)', html_content)
                    if surf_hab_match:
                        result["property_details"]["surface_habitable"] = clean_text(surf_hab_match.group(1))
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and any(term in div.select_one('span').get_text().lower() for term in ['surf habitable', 'surface habitable']):
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["surface_habitable"] = clean_text(strong.get_text(strip=True))
                                    break

            # Surface terrain (Land area)
            if result["property_details"]["surface_terrain"] is None:
                surf_terr_element = soup.find('span', string=lambda text: text and ('Surf terrain' in text or 'Surface terrain' in text) if text else False)
                if surf_terr_element and surf_terr_element.find_next('strong'):
                    result["property_details"]["surface_terrain"] = clean_text(surf_terr_element.find_next('strong').get_text(strip=True))
                else:
                    # Fallback to regex
                    surf_terr_match = re.search(r'Surf terrain\s*:\s*</span>\s*<strong>([^<]+)', html_content)
                    if surf_terr_match:
                        result["property_details"]["surface_terrain"] = clean_text(surf_terr_match.group(1))
                    else:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and any(term in div.select_one('span').get_text().lower() for term in ['surf terrain', 'surface terrain']):
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["surface_terrain"] = clean_text(strong.get_text(strip=True))
                                    break

            # Année construction (Construction year)
            if result["property_details"]["annee_construction"] is None:
                annee_element = soup.find('span', string=lambda text: text and ('Année construction' in text or 'Annee construction' in text) if text else False)
                if annee_element and annee_element.find_next('strong'):
                    result["property_details"]["annee_construction"] = clean_text(annee_element.find_next('strong').get_text(strip=True))
                else:
                    # Try multiple regex patterns for année construction
                    annee_patterns = [
                        r'Ann[ée]e construction\s*:\s*</span>\s*<strong>([^<]+)',
                        r'Ann[ée]e de construction\s*:\s*</span>\s*<strong>([^<]+)'
                    ]
                    
                    for pattern in annee_patterns:
                        annee_match = re.search(pattern, html_content, re.IGNORECASE)
                        if annee_match:
                            result["property_details"]["annee_construction"] = clean_text(annee_match.group(1))
                            break
                    
                    if result["property_details"]["annee_construction"] is None:
                        # Try another approach with block-over divs
                        for div in soup.select('.block-over'):
                            if div.select_one('span') and any(term in div.select_one('span').get_text().lower() for term in ['année construction', 'annee construction']):
                                strong = div.select_one('strong')
                                if strong:
                                    result["property_details"]["annee_construction"] = clean_text(strong.get_text(strip=True))
                                    break
                            
            # Debug message to track extraction success
            print(f"Extracted details - Rooms: {result['property_details']['pieces']}, Year: {result['property_details']['annee_construction']}")
            
        except Exception as e:
            print(f"Error getting property details: {e}")

        # Options
        try:
            # Try direct BeautifulSoup approach first
            option_elements = soup.select('span.col-md-4 strong i.fa-check-square')
            if option_elements:
                options = []
                for element in option_elements:
                    parent = element.parent
                    if parent and parent.get_text():
                        option_text = clean_text(parent.get_text().replace('✓', '').strip())
                        if option_text:
                            options.append(option_text)
                
                if options:
                    result["options"] = options
                else:
                    # Fallback to regex
                    options_matches = re.findall(r'<span class="col-md-4[^>]+><strong>\s*<i class="fa fa-check-square"></i>\s*([^<]+)</strong>', html_content)
                    if options_matches:
                        result["options"] = [clean_text(opt) for opt in options_matches if opt.strip()]
                        
            # If still no options, try another approach with span-opts class
            if not result["options"]:
                option_spans = soup.select('span.span-opts strong')
                if option_spans:
                    result["options"] = [clean_text(span.get_text().replace('✓', '').strip()) for span in option_spans if span.get_text().strip()]
            
        except Exception as e:
            print(f"Error getting options: {e}")

        # Description
        try:
            desc = soup.find('p', itemprop='text')
            if desc:
                result["description"] = clean_text(desc.get_text())
            else:
                # Try finding the description in other ways
                desc_element = soup.find('div', class_='detail-desc')
                if desc_element:
                    p_elements = desc_element.find_all('p')
                    if p_elements:
                        result["description"] = clean_text(" ".join([p.get_text() for p in p_elements]))
        except Exception as e:
            print(f"Error getting description: {e}")

        # Images
        try:
            images = soup.select('div.slider-product img[src]')
            if images:
                result["images"] = list(set([img['src'] for img in images]))
        except Exception as e:
            print(f"Error getting images: {e}")

        return result

    except Exception as e:
        print(f"Error scraping property details: {e}")
        return None

def scrape_property_listings(base_url, page_number, max_retries=3):
    # Construct URL with page number
    url = f"{base_url}?l=0&page={page_number}&tri=1"

    # Set up session with retry logic
    session = requests.Session()
    retry_strategy = Retry(
        total=max_retries,
        backoff_factor=1,  # Will sleep for 1s, then 2s, then 4s between retries
        status_forcelist=[429, 500, 502, 503, 504],
        allowed_methods=["GET"]
    )
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("https://", adapter)

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
        'Accept-Language': 'fr-FR,fr;q=0.9',
        'Connection': 'keep-alive'
    }

    try:
        # Fetch the page with retry logic
        for attempt in range(max_retries):
            try:
                print(f"Scraping page: {url} (Attempt {attempt+1}/{max_retries})")
                response = session.get(url, headers=headers, timeout=30)  # Increased timeout to 30s
                response.raise_for_status()
                break
            except requests.exceptions.RequestException as e:
                if attempt < max_retries - 1:
                    backoff_time = (2 ** attempt) * random.uniform(1, 2)
                    print(f"Error fetching the page (attempt {attempt+1}): {e}")
                    print(f"Waiting {backoff_time:.2f} seconds before retrying...")
                    time.sleep(backoff_time)
                else:
                    print(f"Failed to fetch page {page_number} after {max_retries} attempts")
                    return []

        # Try different encodings
        for encoding in ['utf-8', 'latin1', 'windows-1252']:
            try:
                response.encoding = encoding
                html_content = response.text
                soup = BeautifulSoup(html_content, 'html.parser')
                break
            except UnicodeDecodeError:
                continue

        # Find all property listings
        listings = soup.find_all('div', class_='li-item-list')
        
        if not listings:
            print(f"Warning: No listings found on page {page_number}. Response length: {len(response.text)}")
            # Try to save the HTML for debugging
            with open(f'debug_page_{page_number}.html', 'w', encoding='utf-8') as f:
                f.write(response.text)
            
        properties = []

        for listing in listings:
            try:
                # Extract basic listing information
                title_element = listing.find('a', class_='li-item-list-title')
                title = title_element.get_text(strip=True) if title_element else "No title found"
                title = clean_text(title)

                # Premium tag might not exist for all listings
                premium_tag = listing.find('span', class_='strap-premium')
                premium = premium_tag.get_text(strip=True) if premium_tag else "Standard"

                price_element = listing.find('span', class_='item-box-price')
                price = price_element.get_text(strip=True) if price_element else "Price not specified"
                
                link_element = listing.find('a', class_='li-item-list-title')
                link = link_element['href'] if link_element and 'href' in link_element.attrs else None

                # More robust location finding
                location_element = (
                    listing.find('p', class_='location') or 
                    (listing.find('i', class_='fa-map-marker').find_parent() if listing.find('i', class_='fa-map-marker') else None)
                )
                
                location = "Location not specified"
                if location_element:
                    location = location_element.get_text(' ', strip=True)
                    location = clean_text(location)

                # If location contains comma, split into neighborhood and city
                neighborhood, city = None, None
                if location and ',' in location:
                    parts = [part.strip() for part in location.split(',')]
                    neighborhood = parts[0] if len(parts) > 0 else None
                    city = parts[1] if len(parts) > 1 else None

                # Skip if we don't have a valid link
                if not link:
                    print(f"Skipping listing with no link: {title}")
                    continue

                # Scrape full property details
                full_property_details = scrape_property_details(link, title)

                # Create property dictionary
                property_data = {
                    "title": title,
                    "premium": premium,
                    "price": price,
                    "link": link,
                    "location": location,
                    "neighborhood": neighborhood,
                    "city": city
                }
                
                # Add property details if available
                if full_property_details:
                    property_data.update(full_property_details)

                properties.append(property_data)

                # Add more randomized delay between requests to property details
                time.sleep(random.uniform(1.5, 3.5))

            except Exception as e:
                print(f"Error processing a listing: {e}")
                continue

        return properties

    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Function to save partial data periodically
def save_partial_data(properties, filename='menzili_properties_partial_rest.json'):
    try:
        json_output = json.dumps(properties, indent=2, ensure_ascii=False)
        with open(filename, 'w', encoding='utf-8') as f:
            f.write(json_output)
        print(f"Saved {len(properties)} properties to {filename}")
    except Exception as e:
        print(f"Error saving partial data: {e}")

# Main execution
if __name__ == "__main__":
    # You can change this URL to scrape maisons (houses) instead of apartments
    base_url = "https://www.menzili.tn/immo/vente-appartement-neuf-tunisie"
    # Uncomment the line below to scrape houses instead
    # base_url = "https://www.menzili.tn/immo/vente-maison-tunisie"
    
    all_properties = []
    save_interval = 5  # Save data every 5 pages
    
    # Scrape pages from 241 to 280
    start_page = 241
    end_page = 280
    
    try:
        for page in range(start_page, end_page + 1):
            try:
                # Scrape properties from current page
                page_properties = scrape_property_listings(base_url, page)

                # Add properties to the main list
                all_properties.extend(page_properties)

                # Print progress
                print(f"Completed page {page}. Total properties so far: {len(all_properties)}")

                # Save partial data periodically
                if page % save_interval == 0 or page == end_page:
                    save_partial_data(all_properties)

                # More randomized delay between pages
                delay = random.uniform(3, 7)
                print(f"Waiting {delay:.2f} seconds before next page...")
                time.sleep(delay)

            except Exception as e:
                print(f"Error scraping page {page}: {e}")
                # Save partial data on error
                save_partial_data(all_properties, f'menzili_properties_error_at_page_{page}.json')
                continue

    except KeyboardInterrupt:
        print("\nScraping interrupted by user. Saving collected data...")
        save_partial_data(all_properties, 'menzili_properties_interrupted.json')
    
    # Save the final data
    if all_properties:
        # Convert to JSON
        json_output = json.dumps(all_properties, indent=2, ensure_ascii=False)

        # Save to file
        with open('menzili_properties_data_rest.json', 'w', encoding='utf-8') as f:
            f.write(json_output)

        print("Scraping completed. Data saved to menzili_properties_data_rest.json")
        print(f"Total properties scraped: {len(all_properties)}")
    else:
        print("No properties were scraped. Check the website availability or your network connection.")
# Out:
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=241&tri=1 (Attempt 1/3)
# Scraping details for: Appartement de type S2 bien situé
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre appartement haut standing a rades meliane
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2014
# Scraping details for: Appartement neuf S+3 aux Jinenes Ennasr
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: DUPLEXE MIRIAM (Réf: V1086)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement a vendre de 110 m²
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2010
# Scraping details for: Triplex SANA (Réf: V1201)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 au 1er étage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Scraping details for: Joli appartement 3 pièces et salon
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Coquet appartement S+2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre appartement haut standing Lac 2 Berges du Lac II tunis
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Résidence STAR (Réf: V1123)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+2 à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de haut standing de 99 m2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Spacieux Appartement de haut standing de 118 m2
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: \u0634\u0642\u0629 \u0644\u0644\u0628\u064a\u0639 \u062c\u062f\u064a\u062f\u0629 \u0641\u064a \u0628\u0648\u06a8\u0631\u0646\u064a\u0646
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appt S+3 RDC Mourouj 3, sup 100 m2
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 1995
# Scraping details for: Vendre un appartement à yassmine hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Vendre un appartemement
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Vendre un appartement de 94 m2 à mansoura
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: à vendre 4 appartements à #kélibia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 241. Total properties so far: 20
# Waiting 5.18 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=242&tri=1 (Attempt 1/3)
# Scraping details for: Vendre 3 appartemements style moderne
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: à vendre un complex à kélibia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+2 dans une residence R+2 calme (cote cite what)
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2016
# Scraping details for: 4 appartement + un garage à vendre
# Found pieces with variant 'Piéces (Totale)': 8
# Extracted pieces: 8
# Extracted details - Rooms: 8, Year: 2016
# Scraping details for: Luxe appartement à ain zaghouen nord
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+2 de 84 m² à sahloul
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+2 de 132 m² à sahloul
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+3 de 140 m² à sahloul
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: S+3 de 168 m² à Sahloul
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: S+2 de 140 m² à Sahloul
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+2 de 125 m² à sahloul
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+4 de 220 m² à Sahloul
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: S+2 de 90 m² à Sahloul
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+3 Très Haut Standing
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: None
# Scraping details for: S+2 de 105 m² à Sahloul
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+3 de 160 m² à Sahloul
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: S+1 BIEN MEUBLÉ POUR ÉTUDIANT-ÉTUDIANTE
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2018
# Scraping details for: Appartement PARADIS (Réf: V1134)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre S+2 redidence dorret El menzah 9C
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: A vendre s+2 et bureau T.H.S
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2015
# Completed page 242. Total properties so far: 40
# Waiting 3.39 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=243&tri=1 (Attempt 1/3)
# Scraping details for: Appartement SIRENA (Réf: V824)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Studio s+0 au bord de la mer
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2011
# Scraping details for: Appartement S+3 à Gammarth
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement S+2 à Gamarth
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: 3 appartements s+2 a Kharrouba Hammamet nord
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Une Villa Avec garage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre Un joli appartement S+1
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2015
# Scraping details for: Appartement PECHE (Réf: V1225)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Une superbe villa à ghazella
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement à l\u2019achat surface total 100m2 chauffage central et porte blindée.
# Found pieces with variant 'Piéces (Totale)': 8
# Extracted pieces: 8
# Extracted details - Rooms: 8, Year: None
# Scraping details for: Des beaux appartements à citer ennaser 2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un joli appartement
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2010
# Scraping details for: Un appartement à vendre à borj cedria
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2014
# Scraping details for: Appart route Soukra
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement LYNE (Réf: V340)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement MERMAID (Réf: V1149)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement TOUTI 1 (Réf: V508)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement NEW 2 (Réf: V10Appartement NEW 2 (Réf: V1012)12)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: App a vendre rue med Ali en face carrefour market
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement SAHAR (Réf: V1071)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 243. Total properties so far: 60
# Waiting 5.79 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=244&tri=1 (Attempt 1/3)
# Scraping details for: Appartement DINA (Réf: V1072)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Superbe appartement de 101 m²
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S plus deux au premier
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Belle villa à La soukra de 302m²
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement De Très Haut Standing en Duplex
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Belle appartement s+2
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2010
# Scraping details for: Location Studio Kélibia
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2017
# Scraping details for: Appartement à bir El Bey
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: 1er étage d'une villa
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement S+3 de 152 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Une villa de 327 m² à Carthage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement Duplex S+3 centre ville Kelibia
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A Vendre a El Mouroj
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 1998
# Scraping details for: Appartement NAPOLI (Réf: V1219)Appartement NAPOLI (Réf: V1219)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT S+2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2003
# Scraping details for: Un appartement à vendre à la résidence FOLLA AQUA RESORT Chott Meriam
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2015
# Scraping details for: S+2 très haut standing sokra
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2019
# Scraping details for: Rez de chaussé de type S3 avec jardin
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartemen ta raoued
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Vente appartement S+2 à la soukra
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2016
# Completed page 244. Total properties so far: 80
# Waiting 4.58 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=245&tri=1 (Attempt 1/3)
# Scraping details for: Appartement PARADIS 1 (Réf: V1135)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement ARIELLE (Réf: V721)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Offre des beaux appartements s+1 /s+2 situés à manouba
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2020
# Scraping details for: Appartement manouba
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: Un appartement neuf ala manouba
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2020
# Scraping details for: Villa + 2 appr + commerce
# Found pieces with variant 'Piéces (Totale)': 10+
# Extracted pieces: 10+
# Extracted details - Rooms: 10+, Year: 2000
# Scraping details for: A vendre appartement s+1 au 1ere etage a Tunis
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Superbe appartement à jardins du Carthage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement a citer wahat
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartements neufs à vendre à 200m de Place Pasteur ,TUNIS
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: A vendre appartement de 100 m²
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+2 a borj cedria a vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Apparemment à vendre à Ribat El Medina Sfax
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2006
# Scraping details for: Appartement NAPOLI (Réf: V1219)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement Anoir (Réf: V884)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Résidence MIRNA (Réf: V447)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement HAZEM (Réf: V1255)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Une villa très haut standing divisée en 3 étages à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartements à Mateur
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Spacieux étage de villa
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Completed page 245. Total properties so far: 100
# Saved 100 properties to menzili_properties_partial_rest.json
# Waiting 3.02 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=246&tri=1 (Attempt 1/3)
# Scraping details for: Appartement ZINA (Réf: V1254)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un Coquet Appartement S+2 - HS à Vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2015
# Scraping details for: Appartement F3 centre ville Zarzis
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement de 112 m2 à vendre à borj cedria
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement à vendre à borj cedria 27 246 306
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 a borj cedria à 500 m de la plage.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Tres bel apartment sousse cité riadh
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2016
# Scraping details for: Un magnifique appartement de 65 m² à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un magnifique appartement S+1, en 1er étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+1 situé au 1er étage à hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un superbe apppartement de 95 m² à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Magnifique Appartement en 3éme étages
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 120 m2 à vendre à El Mourouj
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de trés haut standing S2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Des appartements de style S+3 a borj cedria
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+1 avec une belle vue sur mer
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+3 avec une belle vue sur mer
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+1 à Borj Cedria à 500 m de la plage.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un magnifique appartement à vendre occupe le 1ére étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un magnifique appartement à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 246. Total properties so far: 120
# Waiting 3.15 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=247&tri=1 (Attempt 1/3)
# Scraping details for: Appartement S+3 avec piscine à Borj Cedria
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un magnifique appartement S+1 à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+3 a Borj cedria.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+3 en plein zone touristique Borj cedria.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 à Borj Cedria
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Des appartements de style S+2 à El Mourouj 6.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+2 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À vendre Appartement S+2 Khaznadar
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+3 à vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: \u0634\u0642\u0642 \u0644\u0644\u0628\u064a\u0639 \u0641\u064a \u0642\u0644\u064a\u0628\u064a\u0629
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement errouki marina bizerte
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartement s+3 1 ére étage à vendre
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: 10 appartement s+2 et une villa et 9 locaux commerciaux à vendre
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+2 à vendre
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+2 à vendre a ghazella
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+1 et s+2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+1 et s+2
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement s+2 et s+3
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartement s+1 à vendre
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement s+3, s+5 et s+6 des triplex à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 247. Total properties so far: 140
# Waiting 5.36 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=248&tri=1 (Attempt 1/3)
# Scraping details for: Appartement s+2 meublé à louer
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+2 meublè à louer
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement s+1 à louer
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement s+3 à louer meublé A ain zaghouen
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement haut standing jamais habité
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: S+3 et des triplex à vendre a jardin de Carthage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement à vendre s+2, s+3 à borj louzir en cour de construction
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartements à vendre s+3, s+5 et s+6 des triplex
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S 3 jardin de cartahge
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartements s+1 s+2 , s+3 et des villas a soukra à vendre
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement S 3 avec terrasse aux Jardin de Carthage
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement à vendre de 50 m²
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Vente un spacieux S 3
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartements s+2 , s+3 haut standing a la marsa
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S 1 haut standing à vendre dans une petite résidence
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+1 s+2 s+3 a chotrana 1
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: None
# Scraping details for: Un coquette S 1 haut standing jardin de carthage
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+1 s+2 s+3 des duplex et des villas haut standing
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: None
# Scraping details for: A vendre s+2 aux jardins de carthage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 248. Total properties so far: 160
# Waiting 4.46 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=249&tri=1 (Attempt 1/3)
# Scraping details for: Appartement s+2 en cours de finition à Ain Zaghouen nord
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre appartement S+3 à La Soukra
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2005
# Scraping details for: Appartement s+3 et s+4 à jardin de carthage
# Found pieces with variant 'Piéces (Totale)': 7
# Extracted pieces: 7
# Extracted details - Rooms: 7, Year: None
# Scraping details for: A ne pas rater
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A Vendre Appartement neuf aux jardin de carthage
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: Appartement a vendre style américain a fathalla ben arous
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2000
# Scraping details for: LOCATION D\u2019UN S+2 MEUBLÉE A MREZGA HAMMAMET
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement a Hergla-
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Une bonne affaire pour la vente
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartements S+2 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartements S+2 à AFH Hergla-Sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartements S+2 à 100 mètres de la plage, hergla
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+1 à AFH Hergla-Sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+2 à chott_mariem #sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+2 a 20 mètre de la #plage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+2 à akouda chott_mariem .
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Des appartements pieds dans l\u2019eau à chott_mariem sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+2 à chott_mariem .
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un #appartement à #akoud_SOUSSE .
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+1 pied dans l\u2019eau à #chott_mariem
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 249. Total properties so far: 180
# Waiting 4.72 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=250&tri=1 (Attempt 1/3)
# Scraping details for: Un appartement à chott_mariem sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Unappartement S+1 a sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement centre ville en face de l'hôtel mechtel
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2000
# Scraping details for: Appartement a hergla 93809626
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de bon standing de type S3 avec une vue panoramique
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement Gammarth sup
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2010
# Scraping details for: Appartement de type S2 prés de tous commodités
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Adorable bangalow à kantaoui
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+3 au 1 ère étage a cité wahat
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+3 au 5 éme étage à cité wahat
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+2 a l'aouina
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+2 cité wahat
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement de 117.10 m2 a cité wahat
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+2 a chotrana1
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement s+1 a sidi salah
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Apparetement s+3 a borj louzir
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement s+2 a ain zaghouen
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Apparemment s+3 mourouj 1
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Scraping details for: Appartement à vendre chemin de la plage
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: None
# Scraping details for: Appartement Ras Djebel chemin de la plage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 250. Total properties so far: 200
# Saved 200 properties to menzili_properties_partial_rest.json
# Waiting 5.67 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=251&tri=1 (Attempt 1/3)
# Scraping details for: Appartement Menzah 8
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2010
# Scraping details for: Appartement S+2 au 1ér étage dans un cartier calme et sécurisé
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2018
# Scraping details for: à vendre un appartement s+2 à ariana borj louzir ( behi ladghem )
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement rez de chaussée à Al médina jedida 1
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Terrain à 5 min de la mer.hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Luxe appartement totalement rénové à l'aouina
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement usage bureautique a la soukra
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre deux appartements a Picville sfax
# Found pieces with variant 'Piéces (Totale)': 10+
# Extracted pieces: 10+
# Extracted details - Rooms: 10+, Year: 1990
# Scraping details for: Un appartement à vendre à Sidi Selem Vue sur mer
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Beau S+4 spacieux et illuminé dans quartier calme et prisé
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 1998
# Scraping details for: A vendre magnifique maison R+1 avec jardin
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre une maison dans une zone calme a Borj Cedria.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+3 avec une belle vue sur mer
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+1 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Des appartements de style S+3 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Des appartements a vendre de borj cedria
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+1 à chott_mariem sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement S+2 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: #appartement S+1 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement S+3 haut standing situé dans une résidence à #akoud_SOUSSE .
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 251. Total properties so far: 220
# Waiting 5.82 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=252&tri=1 (Attempt 1/3)
# Scraping details for: Appartement rez de chaussée à Ben Arous
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Appartement S+5 cité Elghazella Arina (S+3&studio communicants)
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2015
# Scraping details for: A vendre magnifique Appartement vue sur mer de style S+1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre e Appartement vue sur mer de style S+3 en 2 ème étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre magnifique Appartement vue sur mer
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartement S+1 situé au 1er étage à hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un superbe appartement meublé occupe le 2éme étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appart s+3
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2016
# Scraping details for: A vendre un bel appartement S+1 en RDC à Hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un bel appartement S+1 occupe le 1ére étage à Hammamet Nord
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartement haut standing de type S+2 avec place de parking
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un beau duplex S+1 avec Jardin et Piscine Collectif
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre bel appartement S+2 en RDC avec garage situé dans une zone calme à Hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre magnifique Appartement en 3 éme étages
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre beaux appartements hauts standings de style S+2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre bel appartement en RDC d\u2019un immeuble gardé
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartement dans un emplacement idéal a Hammamet_Nord
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre des beaux appartements hauts standings de style S+1, S+2 et S+3
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre des beaux appartements hauts standing de style S+1, S+2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre S+2 situés à Hammamet centre-ville à 5 min de la plage.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 252. Total properties so far: 240
# Waiting 6.51 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=253&tri=1 (Attempt 1/3)
# Scraping details for: A vendre un bel appartement au RDC
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre magnifique appartement S+1, en 1er étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre un bel appartement en 1er étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre magnifique Appartement en 3éme étages
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: À vendre apparemment haut standing à Ennasr
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un bel appartement hauts standing en 2éme étage à hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: \u0634\u0642\u0642 \u0644\u0644\u0628\u064a\u0639 \u0641\u064a \u0642\u0644\u064a\u0628\u064a\u0629 \u0637\u0631\u064a\u0642 \u0627\u0644\u0628\u062d\u0631
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+2 neuf haut standing vue mer à sahloul 4
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2019
# Scraping details for: Appartement jamais habité prés de la mer
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2019
# Scraping details for: \u062f\u0627\u0631 \u0644\u0644\u0628\u064a\u0639 \u0641\u064a \u0637\u0631\u064a\u0642 \u0627\u0644\u0645\u0646\u0635\u0648\u0631\u0629 \u0642\u0644\u064a\u0628\u064a\u0629
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement presque neuf S+2 à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: TRUSTIMMO PROPOSE IMMOBILIER NEUF A SOUSSE
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: APPARTEMENTS NEUFS DANS UNE NOUVELLE RESIDENCE À MONASTIR
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: TRUSTIMMO PROPOSE APPARTEMENTS NEUFS ET LUXUEUX À HAMMAMET SUD
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: SI VOUS VOULEZ POSSÉDER UN APPARTEMENT À NABEUL, LA CAPITALE - HAMMAMET - MREZGA
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: SUPERBES S+2 ET S+3 NEUFS À mrezga
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: IMMOBILIER NEUFS ET DE TRÈS HAUT STANDING À MREZGA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: S+1 NEUFS ET LUXUEUX À YASMINE HAMMAMET
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: APPARTEMENTS ET DUPLEX DE HAUT STANDING À NABEUL
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: DUPLEX, S+1, S+2, S+3 À YASMINE HAMMAMET DISPONIBLE À LA VENTE
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Completed page 253. Total properties so far: 260
# Waiting 5.56 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=254&tri=1 (Attempt 1/3)
# Scraping details for: APPARTEMENTS HAUT STANDING À JARDINS EL MENZAH 2
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: À VENDRE À ENNASR 2 : S+2 / S+3 NEUFS ET DE HAUT STANDING
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: APPARTEMENTS HAUT STANDING À MANNOUBA
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: ENNASR 2 : IMMOBILIER DE LUXE À VENDRE
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: ENNASR 2 : À VENDRE DES S+2 / S+3 NEUFS ET DE LUXE
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: APPARTEMENTS DE TRÈS HAUT STANDING À ENNASR 2
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: S+3 DE HAUT STANDING À MENZAH 9
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: LUXUEUX S+3 / S+4 DE HAUT STANDING À BARDO
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: LOCAUX COMMERCIAUX : À VENDRE DES LOCAUX DE HAUT STANDING À MOUROUJ 6
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2021
# Scraping details for: VENTE DES LOCAUX COMMERCIAUX À MEDINA JADIDA 3
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: DES APPARTEMENTS S+2 / S+3 NEUFS À MEDINA JADIDA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: Appartement s3 avendre a lycée ezzahra
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: DES APPARTEMENTS DE LUXE À MOUROUJ 6
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: MOUROUJ 6 : APPARTEMENTS DE LUXE À VENDRE
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: Appartements dans une Résidence R+2 de haut standing
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: Appartements dans une Résidence R+2 de haut standing
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: RÉSIDENCE LUXUEUX : S+1 / S+2 / S+3 / VILLAS / DUPLEX
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: DES APPARTEMENTS DE LUXE À CHOTRANA
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: S+2 / S+3 À CITÉ WAHAT AOUINA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: DES S+2 / S+3 NEUFS À AIN ZAGHOUAN NORD
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Completed page 254. Total properties so far: 280
# Waiting 5.87 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=255&tri=1 (Attempt 1/3)
# Scraping details for: LUXUEUX APPARTEMENTS S+2 /S+3 À CHOTRANA
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: DUPLEX / S+3 DE HAUT STANDING À VENDRE À CHOTRANA
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: S+1 / S+2 / S+3 DE HAUT STANDING À CHOTRANA
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: À VENDRE : IMMOBILIER DE LUXE À CHOTRANA
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: S+3 DE HAUT STANDING DISPONIBLE À LA VENTE À CHOTRANA
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: À VENDRE APPARTEMENTS DANS UNE LUXUEUX R+2
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: IMMOBILIER LUXUEUX À JARDINS DU LAC : S+2 / S+3 DE HAUT STANDING
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: JARDINS DE CARTHAGE : S+3 DE HAUT STANDING À VENDRE
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2020
# Scraping details for: À VENDRE : APPARTEMENTS DE LUXE A USAGE BUREAUTIQUE (AIN ZAGHOUAN)
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 2020
# Scraping details for: Appartements au RDC à manzeh 8
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2019
# Scraping details for: AIN ZAGHOUAN : APPARTEMENTS DANS UNE R+7 DE HAUT STANDING
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2020
# Scraping details for: IMMOBILIER DE LUXE : S+1 / S+2 / S+3 À AIN ZAGHOUAN
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2020
# Scraping details for: DUPLEX / TRIPLEX À LA VENTE AUX BERGES DU LAC
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2017
# ...
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2012
# Scraping details for: Adorable appartement jamais habité
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Completed page 273. Total properties so far: 660
# Waiting 3.07 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=274&tri=1 (Attempt 1/3)
# Scraping details for: Appartements & Place Parking à Sousse Hergla
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Apparttement a louer
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: A vendre appartement centre ville
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 1990
# Scraping details for: Adorable appartement avec piscine
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: AV un appartement pré monoprix Nabeul
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: AV un appartement avec piscine à Bni khiar Nabeul
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: AV un appartement a Nabeul
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: AV un studio à Sidi Mahrssi Nabeul 5 min de la plage
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: AV un appartement à Sidi mahrssi Nabeul
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: Un bel appartement de 85 m2 à Nabeul.
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: AV un appartement à 2 mn de la plage
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: 1
# Scraping details for: Port El Kantawi
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Joli appartement à chatt mariem
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2019
# Scraping details for: Appartement de 120 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 91 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 65 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement à vendre de 175 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement à vendre de 109 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 140 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 200 m2 à vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 274. Total properties so far: 680
# Waiting 3.45 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=275&tri=1 (Attempt 1/3)
# Scraping details for: Appartement de 124 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 110m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement à Hammamet côté hôtel Ribat
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un sublime appartement de luxe
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+2 à vendre pied dans l'eau avec vue magnifique
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre appartement front de la mer pieds dans l'eau mahdia
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: RDC s+3 avec jardin très haut standing près hotel mahdia beach
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Jolie appartement S2 avec une vue panoramique
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Offer ne pas rater
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: 2010
# Scraping details for: Appartement à yassmine hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN APPARTEMENT HAMMAMET
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: AV un appartement de 70 M2 a Hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+2 Rz el corniche pied dans l'eau
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement s+2 très luxueux en plein zone touristique
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: A vendre s+2 très spacieux proche de la mer au c\u0153ur de la zone touristique
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement pied dans l'eau à bas prix à rejiche
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Appartement ABLA (Réf: V1140)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Résidence TAHITI 2 (Réf: V1184)Résidence TAHITI 2 m serine
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Très beau s+2 et un studio a ain zaghouan nord. La marsa
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2015
# Scraping details for: Location vacance TAZARKA
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: 2008
# Completed page 275. Total properties so far: 700
# Saved 700 properties to menzili_properties_partial_rest.json
# Waiting 4.91 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=276&tri=1 (Attempt 1/3)
# Scraping details for: Avendre un RDC
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: A vendre Appartement Cap Marina Monastir vue Mer
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN magnifique appartement a vendre de 54 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un bel appartement a vendre de 85 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un bel appartement a vendre de 110 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement haut standing s+4 a rades meliane
# Found pieces with variant 'Piéces (Totale)': 6
# Extracted pieces: 6
# Extracted details - Rooms: 6, Year: 2014
# Scraping details for: Vente d un appartement a mourouj 3
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: None
# Scraping details for: Un bel appartement a vendre de 65 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S2 à Ezzahra coté salon de thé le voilier
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN magnifique appartement a vendre de 120 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN magnifique appartement a vendre en 2 éme étage
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un bel appartement a vendre de 70 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un bel appartement a vendre de 144 m2
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Superbe appartment à la Médina de Hammamet
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement à rades Meleine
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: AV. APPARTEMENT À AIN ZAGHOUAN
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2003
# Scraping details for: AV un beau duplex S+2 avec terrasse à AFH MREZGA
# Found pieces with variant 'Piéces (Totale)': 1
# Extracted pieces: 1
# Extracted details - Rooms: 1, Year: None
# Scraping details for: Appartement S+3 À vendre ezzahra lycée sous les arcades à côté la gare
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT S+2 À ENNKHILET EN EXCELLENT ÉTAT
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2012
# Scraping details for: A vendre apparemment s+4 à prix cassé
# Found pieces with variant 'Piéces (Totale)': 4
# Extracted pieces: 4
# Extracted details - Rooms: 4, Year: None
# Completed page 276. Total properties so far: 720
# Waiting 4.97 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=277&tri=1 (Attempt 1/3)
# Scraping details for: Des beaux appartements a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un bel appartement S+1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement a vendre sousse
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2013
# Scraping details for: Appartement dans un quartier calme Riadh Al Andalous
# Found pieces with variant 'Piéces (Totale)': 2
# Extracted pieces: 2
# Extracted details - Rooms: 2, Year: None
# Scraping details for: Joli appartement à un prix incroyable
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2014
# Scraping details for: Superbe appartement avec entrée privative
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2009
# Scraping details for: Spacieux appartement vue sur mer à bas prix
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2014
# Scraping details for: Un grand appartement a hammamet centre ville
# Found pieces with variant 'Piéces (Totale)': 5
# Extracted pieces: 5
# Extracted details - Rooms: 5, Year: 2003
# Scraping details for: Un appartement à Mrezga
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2015
# Scraping details for: Apt de luxe Nasr 2
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2014
# Scraping details for: Appartement GAMRA 3 (Réf: V1048)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement SARAH (Réf: V844)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement LA BADIRA 5 (Réf: V916)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement MOHTADI (Réf: V798)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement en 1 er étage avec PISCINE à AFH mrezga.
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2016
# Scraping details for: S+2 Haute Standing à soukra
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+3 A RIADH LANDALOUS
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN BEAU APPARTEMENT A RAOUED
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN APPARTEMENT S+4 très haut standing
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Apparemment à rte taniour km2 sfax
# Found pieces with variant 'Piéces (Totale)': 3
# Extracted pieces: 3
# Extracted details - Rooms: 3, Year: 2019
# Completed page 277. Total properties so far: 740
# Waiting 4.57 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=278&tri=1 (Attempt 1/3)
# Scraping details for: Appartement de 120 m2 a vendre
# Extracted pieces: None
# Extracted details - Rooms: None, Year: 2020
# Scraping details for: APPARTEMENT DE BON STANDING
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Un appartement a citer saha
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: S+2 haut standing
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN APPARTEMENT DE 120 M2 HAUT STANDING
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement EL BHAR 1 (Réf: V053)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement OLIVIA 2 (Réf: V1126)
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: OFFRE EXCEPTIONNELLE
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: DES APPARTEMENTS A PRIX CHOC
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT S+1 HAUT STANDING
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT DIRECT PROMOTEUR
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT LUXE A SOUKRA
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT HAUT STANDING
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: APPARTEMENT DE 81 M² A SOUKRA
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN S+2 A AOUINA
# Failed to fetch details (attempt 1): HTTPSConnectionPool(host='www.menzili.tn', port=443): Max retries exceeded with url: /annonce/un-s-2-a-aouina-ariana-lasoukra-33105 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='www.menzili.tn', port=443): Read timed out. (read timeout=30)")). Retrying in 1.53s...
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: DES APPARTEMENTS A CHOTRANA1
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: DES APPARTEMENT A NE PAS RATEZ
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: Appartement de 95m²
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: DES APPARTEMENTS ET DES TRIPLEX
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Scraping details for: UN S+2 A SOUKRA
# Extracted pieces: None
# Extracted details - Rooms: None, Year: None
# Completed page 278. Total properties so far: 760
# Waiting 5.20 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=279&tri=1 (Attempt 1/3)
# Warning: No listings found on page 279. Response length: 199
# Completed page 279. Total properties so far: 760
# Waiting 4.46 seconds before next page...
# Scraping page: https://www.menzili.tn/immo/vente-appartement-neuf-tunisie?l=0&page=280&tri=1 (Attempt 1/3)
# Warning: No listings found on page 280. Response length: 199
# Completed page 280. Total properties so far: 760
# Saved 760 properties to menzili_properties_partial_rest.json
# Waiting 3.30 seconds before next page...
# Scraping completed. Data saved to menzili_properties_data_rest.json
# Total properties scraped: 760
