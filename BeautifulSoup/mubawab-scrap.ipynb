# %%
# Import necessary libraries
import requests
from bs4 import BeautifulSoup
import json
from datetime import datetime
import time
import random
import urllib.parse

print("🚀 Libraries imported successfully!")

def extract_detailed_characteristics(url, headers):
    try:
        # URL validation
        if not url or not url.startswith('http'):
            print(f"❌ Invalid URL: {url}")
            return {}
        
        # Send request with headers
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        
        # Parse HTML
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find characteristics block
        char_block = soup.find('div', class_='blockProp caractBlockProp')
        
        if not char_block:
            return {}
        
        # Extract main features
        detailed_chars = {}
        main_features = char_block.find_all('div', class_='adMainFeature')
        
        for feature in main_features:
            label_elem = feature.find('p', class_='adMainFeatureContentLabel')
            value_elem = feature.find('p', class_='adMainFeatureContentValue')
            
            if label_elem and value_elem:
                label = label_elem.get_text(strip=True)
                value = value_elem.get_text(strip=True)
                detailed_chars[label] = value
        
        return detailed_chars
    
    except Exception as e:
        print(f"❌ Error extracting characteristics: {str(e)}")
        return {}

def scrape_mubawab_listings(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }

    try:
        # Send HTTP request
        print(f"🌐 Fetching page: {url}")
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()

        # Parse HTML content
        print("📋 Parsing HTML...")
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find listing containers
        listings = soup.find_all('div', class_='listingBox')
        print(f"🔍 Found {len(listings)} listings")

        data = []
        
        for i, listing in enumerate(listings):
            try:
                # Extract basic property information
                title_elem = listing.find('h2', class_='listingTit')
                price_elem = listing.find('span', class_='priceTag')
                location_elem = listing.find('span', class_='listingH3')
                
                # Print the title being scraped
                title_text = title_elem.get_text(strip=True) if title_elem else 'No Title'
                print(f"📑 Scraping house #{i+1}: {title_text}")

                # Link and ID extraction
                link_elem = listing.find('a', href=True)
                ad_id_elem = listing.find('input', class_='adId')

                # Image URL extraction
                image_elem = listing.find('img', class_='sliderImage')
                image_url = None
                if image_elem:
                    image_url = (image_elem.get('data-lazy') or
                                 image_elem.get('src') or
                                 image_elem.get('data-src'))

                # Full link handling
                full_link = ''
                if link_elem:
                    href = link_elem.get('href', '').strip()
                    if href:
                        full_link = urllib.parse.urljoin('https://www.mubawab.tn', href) if not href.startswith('http') else href

                # Detailed characteristics extraction
                detailed_chars = {}
                if full_link:
                    print(f"  ↪ Getting details from: {full_link}")
                    time.sleep(random.uniform(0.5, 1.5))  # Respectful scraping
                    detailed_chars = extract_detailed_characteristics(full_link, headers)

                # Prepare listing data
                listing_data = {
                    'title': title_text,
                    'price': price_elem.get_text(strip=True) if price_elem else 'No Price',
                    'location': location_elem.get_text(strip=True) if location_elem else 'No Location',
                    'link': full_link,
                    'ad_id': ad_id_elem['value'] if ad_id_elem else 'No Ad ID',
                    'image_url': image_url or 'No Image',
                    'detailed_characteristics': detailed_chars
                }

                # Property features extraction
                property_features = {}
                feature_mapping = {
                    'icon-triangle': 'area',
                    'icon-house-boxes': 'total_rooms',
                    'icon-bed': 'bedrooms',
                    'icon-bath': 'bathrooms'
                }

                detail_features = listing.find_all('div', class_='adDetailFeature')
                for feature in detail_features:
                    icon = feature.find('i')
                    text = feature.find('span')

                    if icon and text:
                        icon_classes = icon.get('class', [])
                        for icon_class in icon_classes:
                            if icon_class in feature_mapping:
                                feature_key = feature_mapping[icon_class]
                                feature_value = text.get_text(strip=True)
                                property_features[feature_key] = feature_value
                                break

                # Ensure features are populated
                listing_data['features'] = property_features

                # Extract amenities
                amenities = listing.find_all('div', class_='adFeature')
                amenities_list = [amenity.get_text(strip=True) for amenity in amenities if amenity.get_text(strip=True)]
                listing_data['amenities'] = amenities_list

                listing_data['scraped_at'] = datetime.now().isoformat()

                data.append(listing_data)
                print(f"  ✅ Successfully scraped: {title_text}")

            except Exception as e:
                print(f"❌ Error processing a listing: {str(e)}")
                continue

        print(f"🏠 Completed page with {len(data)} houses successfully scraped")
        return data

    except requests.exceptions.RequestException as e:
        print(f"❌ Error fetching the page: {e}")
        return None
    except Exception as e:
        print(f"❌ An error occurred: {e}")
        return None

def scrape_multiple_pages():
    # Create a timestamp for the output file
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    json_filename = f'mubawab_properties_{timestamp}.json'
    
    # List to store all listings
    all_listings = []
    total_scraped = 0
    
    # Loop through pages
    for i in range(1, 291):  # Adjust range as needed
        url = f"https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:{i}"
        
        print(f"\n{'='*50}")
        print(f"🔄 Starting to scrape page {i} of 290")
        print(f"{'='*50}\n")
        
        # Scrape listings for current page
        listings_data = scrape_mubawab_listings(url)
        
        if listings_data:
            # Extend the all_listings with current page's listings
            all_listings.extend(listings_data)
            total_scraped += len(listings_data)
            print(f"📊 Processed page {i}: Added {len(listings_data)} listings")
            print(f"📈 Total properties scraped so far: {total_scraped}")
        else:
            print(f"❌ Failed to scrape page {i}")
        
        # Add a pause between pages to be respectful
        if i < 290:  # Don't wait after the last page
            wait_time = random.uniform(2, 5)
            print(f"⏱️ Waiting {wait_time:.1f} seconds before the next page...")
            time.sleep(wait_time)
    
    # Save all listings to a single JSON file
    if all_listings:
        with open(json_filename, 'w', encoding='utf-8') as f:
            json.dump(all_listings, f, ensure_ascii=False, indent=2)
        
        print(f"\n✅ Successfully scraped {len(all_listings)} total listings")
        print(f"💾 Data saved to '{json_filename}'")
        
        # Print first listing as sample
        print("\n📝 Sample listing:")
        print(json.dumps(all_listings[0], indent=2, ensure_ascii=False))
    else:
        print("\n❌ Scraping failed. No data was saved.")

# Execute the scraping process
if __name__ == "__main__":
    print("🏘️ Starting Mubawab property scraper")
    print("⏰ Process started at:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
    
    start_time = time.time()
    scrape_multiple_pages()
    
    elapsed_time = time.time() - start_time
    hours, remainder = divmod(elapsed_time, 3600)
    minutes, seconds = divmod(remainder, 60)
    
    print("\n⌛ Total execution time: {:02}:{:02}:{:02}".format(
        int(hours), int(minutes), int(seconds)))
    print("🏁 Scraping process completed!")
# Out:
# 🚀 Libraries imported successfully!
# 🏘️ Starting Mubawab property scraper
# ⏰ Process started at: 2025-03-30 16:47:14
#
# ==================================================
# 🔄 Starting to scrape page 1 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:1
# 📋 Parsing HTML...
# 🔍 Found 35 listings
# 📑 Scraping house #1: Appartement en vente à La Soukra
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8105136/un-appartement-s2-de-110-m%C2%B2-%C3%A0-rades
#   ✅ Successfully scraped: Un Appartement S2 de 110 m² à Rades
# 📑 Scraping house #33: Un appartement S2 à la Nouvelle Médina D. Promoteur
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8091812/un-appartement-s2-%C3%A0-la-nouvelle-m%C3%A9dina-d-promoteur
#   ✅ Successfully scraped: Un appartement S2 à la Nouvelle Médina D. Promoteur
# 📑 Scraping house #34: Un Appartement S1 à Nouvelle Médina Vente direc
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8097212/un-appartement-s1-%C3%A0-nouvelle-m%C3%A9dina-vente-direc
#   ✅ Successfully scraped: Un Appartement S1 à Nouvelle Médina Vente direc
# 📑 Scraping house #35: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 35 houses successfully scraped
# 📊 Processed page 3: Added 35 listings
# 📈 Total properties scraped so far: 105
# ⏱️ Waiting 2.5 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 4 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:4
# 📋 Parsing HTML...
# 🔍 Found 35 listings
# 📑 Scraping house #1: Beau DUPLEX à vendre
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/7731742/beau-duplex-%C3%A0-vendre
#   ✅ Successfully scraped: Beau DUPLEX à vendre
# 📑 Scraping house #2: Bel appartement à vendre
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/7845703/bel-appartement-%C3%A0-vendre
#   ✅ Successfully scraped: Bel appartement à vendre
# 📑 Scraping house #3: Appartement à l'achat à Ain Zaghouan Nord
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8009342/appartement-%C3%A0-l-achat-%C3%A0-ain-zaghouan-nord
#   ✅ Successfully scraped: Appartement à l'achat à Ain Zaghouan Nord
# 📑 Scraping house #4: Vente d'un bel appartement à Cité el Ghazela. Surface de 105...
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8035989/vente-d-un-bel-appartement-%C3%A0-cit%C3%A9-el-ghazela-surface-de-105-m%C2%B2
#   ✅ Successfully scraped: Vente d'un bel appartement à Cité el Ghazela. Surface de 105...
# 📑 Scraping house #5: Luxueux S2 à vendre
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/6974432/luxueux-s2-%C3%A0-vendre
#   ✅ Successfully scraped: Luxueux S2 à vendre
# 📑 Scraping house #6: Superbe S2 Neuf à la nouvelle soukra: Projet SITS
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8028206/superbe-s2-neuf-%C3%A0-la-nouvelle-soukra-projet-sits
#   ✅ Successfully scraped: Superbe S2 Neuf à la nouvelle soukra: Projet SITS
# 📑 Scraping house #7: Bel appartement à vendre à Chotrana 1
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/7854981/bel-appartement-%C3%A0-vendre-%C3%A0-chotrana-1
#   ✅ Successfully scraped: Bel appartement à vendre à Chotrana 1
# 📑 Scraping house #8: Résidence" La Régence "
#   ↪ Getting details from: https://www.mubawab.tn/fr/p/4019/r%C3%A9sidence-la-r%C3%A9gence-
#   ✅ Successfully scraped: Résidence" La Régence "
# 📑 Scraping house #9: Appartement à vendre aux Jardins de Carthage. Surface totale...
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/7907082/appartement-%C3%A0-vendre-aux-jardins-de-carthage-surface-totale-116-m%C2%B2
#   ✅ Successfully scraped: Appartement à vendre aux Jardins de Carthage. Surface totale...
# 📑 Scraping house #10: S2 au RDC avec jardin à La Marsa
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8053685/s2-%C3%A0-vendre-maxula-city-rad%C3%A8s-a-2-7
#   ✅ Successfully scraped: S2 à vendre maxula city radès A 2 7
# 📑 Scraping house #25: Un appartement S2 à Nouvelle Médina Direct Prom
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8097210/un-appartement-s2-%C3%A0-nouvelle-m%C3%A9dina-direct-prom
#   ✅ Successfully scraped: Un appartement S2 à Nouvelle Médina Direct Prom
# 📑 Scraping house #26: Ferme de  ***-****** m² à Borj Amri
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8070436/ferme-de-14-370-m%C2%B2-%C3%A0-borj-amri
#   ✅ Successfully scraped: Ferme de  ***-****** m² à Borj Amri
# 📑 Scraping house #27: Un Hall2 de 80m² à La Nouvelle Medina
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8110372/un-hall2-de-80m%C2%B2-%C3%A0-la-nouvelle-medina
#   ✅ Successfully scraped: Un Hall2 de 80m² à La Nouvelle Medina
# 📑 Scraping house #28: Appartement S1 en vente
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8022051/appartement-s1-en-vente
#   ✅ Successfully scraped: Appartement S1 en vente
# 📑 Scraping house #29: S2 en vente
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8093522/s2-en-vente
#   ✅ Successfully scraped: S2 en vente
# 📑 Scraping house #30: S1 direct promoteur à khzema EST
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7976143/s1-direct-promoteur-%C3%A0-khzema-est
#   ✅ Successfully scraped: S1 direct promoteur à khzema EST
# 📑 Scraping house #31: Duplex S3 en vente
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8079822/duplex-s3-en-vente
#   ✅ Successfully scraped: Duplex S3 en vente
# 📑 Scraping house #32: S1 en vente
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8078384/s1-en-vente
#   ✅ Successfully scraped: S1 en vente
# 📑 Scraping house #33: Appartement S2 en vente
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8021943/appartement-s2-en-vente
#   ✅ Successfully scraped: Appartement S2 en vente
# 📑 Scraping house #34: Vente Villa Al Mawj S4
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8105270/vente-villa-al-mawj-s4
#   ✅ Successfully scraped: Vente Villa Al Mawj S4
# 📑 Scraping house #35: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 35 houses successfully scraped
# 📊 Processed page 4: Added 35 listings
# 📈 Total properties scraped so far: 140
# ⏱️ Waiting 4.7 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 5 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:5
# 📋 Parsing HTML...
# 🔍 Found 35 listings
# 📑 Scraping house #1: Bel appartement à vendre à Rades A 2 12
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8053702/bel-appartement-%C3%A0-vendre-%C3%A0-rades-a-2-12
#   ✅ Successfully scraped: Bel appartement à vendre à Rades A 2 12
# 📑 Scraping house #2: Appartement à l'achat à Sahloul 4
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8104598/appartement-%C3%A0-l-achat-%C3%A0-sahloul-4
#   ✅ Successfully scraped: Appartement à l'achat à Sahloul 4
# 📑 Scraping house #3: Bel Appartement S2 jamais habité AVEC TERASSE 57m²
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/7630834/bel-appartement-s2-jamais-habit%C3%A9-avec-terasse-57m%C2%B2
#   ✅ Successfully scraped: Bel Appartement S2 jamais habité AVEC TERASSE 57m²
# 📑 Scraping house #4: Bel appartement à vendre à Cité Bou Mhel
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/8032147/opportunit%C3%A9-d-investissement-s1-%C3%A0-cit%C3%A9-el-wafa
#   ✅ Successfully scraped: Opportunité d'investissement S1 à Cité el wafa
# 📑 Scraping house #34: À vendre Villa de 135m² sur un terrain de 269m²
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7878567/%C3%A0-vendre-villa-de-135m%C2%B2-sur-un-terrain-de-269m%C2%B2
#   ✅ Successfully scraped: À vendre Villa de 135m² sur un terrain de 269m²
# 📑 Scraping house #35: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 35 houses successfully scraped
# 📊 Processed page 5: Added 35 listings
# 📈 Total properties scraped so far: 175
# ⏱️ Waiting 3.7 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 6 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:6
# 📋 Parsing HTML...
# 🔍 Found 35 listings
# 📑 Scraping house #1: A vendre un grand S2 à El Manzah 9C
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/7901654/a-vendre-un-grand-s2-%C3%A0-el-manzah-9c
#   ✅ Successfully scraped: A vendre un grand S2 à El Manzah 9C
# 📑 Scraping house #2: Bel appartement S1 avec Jardin à Jardin de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8080203/bel-appartement-s1-avec-jardin-%C3%A0-jardin-de-carthage
#   ✅ Successfully scraped: Bel appartement S1 avec Jardin à Jardin de Carthage
# 📑 Scraping house #3: Superbe appartement S3 à Jardin de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8029518/superbe-appartement-s3-%C3%A0-jardin-de-carthage
#   ✅ Successfully scraped: Superbe appartement S3 à Jardin de Carthage
# 📑 Scraping house #4: Appartement S3 à Jardin de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8029517/appartement-s3-%C3%A0-jardin-de-carthage
#   ✅ Successfully scraped: Appartement S3 à Jardin de Carthage
# 📑 Scraping house #5: Appartement S2 à Jardin de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8080204/appartement-s2-%C3%A0-jardin-de-carthage
#   ✅ Successfully scraped: Appartement S2 à Jardin de Carthage
# 📑 Scraping house #6: Appartement S1 à Jardin de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8029512/appartement-s1-%C3%A0-jardin-de-carthage
#   ✅ Successfully scraped: Appartement S1 à Jardin de Carthage
# 📑 Scraping house #7: Appartement à vendre à Les Jardins de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8029514/appartement-%C3%A0-vendre-%C3%A0-les-jardins-de-carthage
#   ✅ Successfully scraped: Appartement à vendre à Les Jardins de Carthage
# 📑 Scraping house #8: Résidence Floria - Cité el Ghazela
#   ↪ Getting details from: https://www.mubawab.tn/fr/p/3896/r%C3%A9sidence-floria-cit%C3%A9-el-ghazela
#   ✅ Successfully scraped: Résidence Floria - Cité el Ghazela
# 📑 Scraping house #9: Vente appartement S2 à Jardin de Carthage
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8029515/vente-appartement-s2-%C3%A0-jardin-de-carthage
#   ✅ Successfully scraped: Vente appartement S2 à Jardin de Carthage
# 📑 Scraping house #10: S2 avec Grand terrasse à Ain Zaghouan nord
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8100697/s2-avec-grand-terrasse-%C3%A0-ain-zaghouan-nord
#   ✅ Successfully scraped: S2 avec Grand terrasse à Ain Zaghouan nord
# 📑 Scraping house #11: Vente d'un bel appartement à Rades A 4 11
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/8053652/vente-d-un-bel-appartement-%C3%A0-rades-a-4-11
#   ✅ Successfully scraped: Vente d'un bel appartement à Rades A 4 11
# 📑 Scraping house #12: Appartement à vendre à Sfax Ville REF C24
#   ↪ Getting details from: https://www.mubawab.tn/fr/pa/
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/6850261/superbe-villa-moderne-%C3%A0-la-soukra
#   ✅ Successfully scraped: Superbe Villa moderne à La Soukra
# 📑 Scraping house #31: Vente Villa Seline à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7319490/vente-villa-seline-%C3%A0-hammamet
#   ✅ Successfully scraped: Vente Villa Seline à Hammamet
# 📑 Scraping house #32: Belle résidence à la corniche à 200m de la mer
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7559147/belle-r%C3%A9sidence-%C3%A0-la-corniche-%C3%A0-200m-de-la-mer
#   ✅ Successfully scraped: Belle résidence à la corniche à 200m de la mer
# 📑 Scraping house #33: Une villa à moins de 100m de la plage
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7398528/une-villa-%C3%A0-moins-de-100m-de-la-plage
#   ✅ Successfully scraped: Une villa à moins de 100m de la plage
# 📑 Scraping house #34: Vente appartement pied dans l'eau
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7550191/vente-appartement-pied-dans-l-eau
#   ✅ Successfully scraped: Vente appartement pied dans l'eau
# 📑 Scraping house #35: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 35 houses successfully scraped
# 📊 Processed page 285: Added 35 listings
# 📈 Total properties scraped so far: 9975
# ⏱️ Waiting 4.4 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 286 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:286
# 📋 Parsing HTML...
# 🔍 Found 25 listings
# 📑 Scraping house #1: Vente Villa Sofia à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7518217/vente-villa-sofia-%C3%A0-hammamet
#   ✅ Successfully scraped: Vente Villa Sofia à Hammamet
# 📑 Scraping house #2: Appartement à vendre 108
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7545227/appartement-%C3%A0-vendre-108
#   ✅ Successfully scraped: Appartement à vendre 108
# 📑 Scraping house #3: Vente Duplex Amine à Hammamet Nord
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7440681/vente-duplex-amine-%C3%A0-hammamet-nord
#   ✅ Successfully scraped: Vente Duplex Amine à Hammamet Nord
# 📑 Scraping house #4: Vente Villa Thomas à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7319496/vente-villa-thomas-%C3%A0-hammamet
#   ✅ Successfully scraped: Vente Villa Thomas à Hammamet
# 📑 Scraping house #5: Vente Appartement Nour à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7318854/vente-appartement-nour-%C3%A0-hammamet
#   ✅ Successfully scraped: Vente Appartement Nour à Hammamet
# 📑 Scraping house #6: Résidence El Bousten à Hammamet Sud
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/6961273/r%C3%A9sidence-el-bousten-%C3%A0-hammamet-sud
#   ✅ Successfully scraped: Résidence El Bousten à Hammamet Sud
# 📑 Scraping house #7: Vente Appartement Sirene à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7360519/vente-appartement-sirene-%C3%A0-hammamet
#   ✅ Successfully scraped: Vente Appartement Sirene à Hammamet
# 📑 Scraping house #8: Résidence" La Régence "
#   ↪ Getting details from: https://www.mubawab.tn/fr/p/4019/r%C3%A9sidence-la-r%C3%A9gence-
#   ✅ Successfully scraped: Résidence" La Régence "
# 📑 Scraping house #9: Vente Appartement Dalia 01
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7321136/vente-appartement-dalia-01
#   ✅ Successfully scraped: Vente Appartement Dalia 01
# 📑 Scraping house #10: Belle maison à ERRIADH Djerba
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/6728151/belle-maison-%C3%A0-erriadh-djerba
#   ✅ Successfully scraped: Belle maison à ERRIADH Djerba
# 📑 Scraping house #11: Vente Villa Maher à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7319516/vente-villa-maher-%C3%A0-hammamet
#   ✅ Successfully scraped: Vente Villa Maher à Hammamet
# 📑 Scraping house #12: Villa Flamant Rose
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7372311/villa-flamant-rose
#   ✅ Successfully scraped: Villa Flamant Rose
# 📑 Scraping house #13: Coquette villa avec piscine à Gammarth
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7419891/coquette-villa-avec-piscine-%C3%A0-gammarth
#   ✅ Successfully scraped: Coquette villa avec piscine à Gammarth
# 📑 Scraping house #14: Vente Villa Pawla à Hammamet Nord
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7343441/vente-villa-pawla-%C3%A0-hammamet-nord
#   ✅ Successfully scraped: Vente Villa Pawla à Hammamet Nord
# 📑 Scraping house #15: A vendre S2 à Ain zaghoun
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7450930/a-vendre-s2-%C3%A0-ain-zaghoun
#   ✅ Successfully scraped: A vendre S2 à Ain zaghoun
# 📑 Scraping house #16: Vente Villa cloé à Yasmine Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7415282/vente-villa-clo%C3%A9-%C3%A0-yasmine-hammamet
#   ✅ Successfully scraped: Vente Villa cloé à Yasmine Hammamet
# 📑 Scraping house #17: A Vendre S3 avec Terrasse à Ennasr 2
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7387901/a-vendre-s3-avec-terrasse-%C3%A0-ennasr-2
#   ✅ Successfully scraped: A Vendre S3 avec Terrasse à Ennasr 2
# 📑 Scraping house #18: Triplex Moderne à La Marsa les pins
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7344521/triplex-moderne-%C3%A0-la-marsa-les-pins
#   ✅ Successfully scraped: Triplex Moderne à La Marsa les pins
# 📑 Scraping house #19: Maison de campagne
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7368273/maison-de-campagne
#   ✅ Successfully scraped: Maison de campagne
# 📑 Scraping house #20: Opportunité à saisir
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7312036/opportunit%C3%A9-%C3%A0-saisir
#   ✅ Successfully scraped: Opportunité à saisir
# 📑 Scraping house #21: Magnifique villa S4 à Gammarth
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7252416/magnifique-villa-s4-%C3%A0-gammarth
#   ✅ Successfully scraped: Magnifique villa S4 à Gammarth
# 📑 Scraping house #22: Quadruplex villa style américain sous sol à
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7250311/quadruplex-villa-style-am%C3%A9ricain-sous-sol-%C3%A0
#   ✅ Successfully scraped: Quadruplex villa style américain sous sol à
# 📑 Scraping house #23: À vendre Villa de Maître Exceptionnelle à Hammamet
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7177420/%C3%A0-vendre-villa-de-ma%C3%AEtre-exceptionnelle-%C3%A0-hammamet
#   ✅ Successfully scraped: À vendre Villa de Maître Exceptionnelle à Hammamet
# 📑 Scraping house #24: Villa à menzah 9 à vendre
#   ↪ Getting details from: https://www.mubawab.tn/fr/a/7008329/villa-%C3%A0-menzah-9-%C3%A0-vendre
#   ✅ Successfully scraped: Villa à menzah 9 à vendre
# 📑 Scraping house #25: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 25 houses successfully scraped
# 📊 Processed page 286: Added 25 listings
# 📈 Total properties scraped so far: 10000
# ⏱️ Waiting 3.2 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 287 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:287
# 📋 Parsing HTML...
# 🔍 Found 1 listings
# 📑 Scraping house #1: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 1 houses successfully scraped
# 📊 Processed page 287: Added 1 listings
# 📈 Total properties scraped so far: 10001
# ⏱️ Waiting 4.3 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 288 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:288
# 📋 Parsing HTML...
# 🔍 Found 1 listings
# 📑 Scraping house #1: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 1 houses successfully scraped
# 📊 Processed page 288: Added 1 listings
# 📈 Total properties scraped so far: 10002
# ⏱️ Waiting 4.6 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 289 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:289
# 📋 Parsing HTML...
# 🔍 Found 1 listings
# 📑 Scraping house #1: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 1 houses successfully scraped
# 📊 Processed page 289: Added 1 listings
# 📈 Total properties scraped so far: 10003
# ⏱️ Waiting 2.1 seconds before the next page...
#
# ==================================================
# 🔄 Starting to scrape page 290 of 290
# ==================================================
#
# 🌐 Fetching page: https://www.mubawab.tn/fr/cc/immobilier-a-vendre-all:sc:apartment-sale,farm-sale,house-sale,other-sale,villa-sale:p:290
# 📋 Parsing HTML...
# 🔍 Found 1 listings
# 📑 Scraping house #1: No Title
#   ✅ Successfully scraped: No Title
# 🏠 Completed page with 1 houses successfully scraped
# 📊 Processed page 290: Added 1 listings
# 📈 Total properties scraped so far: 10004
#
# ✅ Successfully scraped 10004 total listings
# 💾 Data saved to 'mubawab_properties_20250330_164714.json'
#
# 📝 Sample listing:
# {
#   "title": "Appartement en vente à La Soukra",
#   "price": "Prix à consulter",
#   "location": "La Soukra, La Soukra",
#   "link": "https://www.mubawab.tn/fr/pa/8038583/appartement-en-vente-%C3%A0-la-soukra",
#   "ad_id": "8038583",
#   "image_url": "https://www.mubawab-media.com/ad/8/038/583F/h/IMG_6862_79222112_79244395.avif",
#   "detailed_characteristics": {
#     "Type de bien": "Appartement",
#     "Etat": "Nouveau",
#     "Etat du bien": "Moins d'un an",
#     "Type du sol": "Marbre",
#     "Standing": "Haut standing",
#     "État": "En cours de construction",
#     "Livraison:": "janvier 2025"
#   },
#   "features": {
#     "area": "93\n\t\t\t\t\t\tm²",
#     "total_rooms": "2 Pièces",
#     "bedrooms": "1 Chambre",
#     "bathrooms": "1 Salle de bain"
#   },
#   "amenities": [
#     "Jardin",
#     "Garage",
#     "Ascenseur",
#     "Climatisation",
#     "Chauffage central",
#     "Sécurité",
#     "Cuisine équipée",
#     "Four"
#   ],
#   "scraped_at": "2025-03-30T16:47:18.752488"
# }
#
# ⌛ Total execution time: 06:04:53
# 🏁 Scraping process completed!
